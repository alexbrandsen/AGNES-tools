# %%
#load and install required packages

# %%
#install required packages
# %pip install git+https://github.com/MeMartijn/updated-sklearn-crfsuite.git#egg=sklearn_crfsuite
# %pip install scikit_learn
# %pip install nltk
# %pip install seaborn
# Out:
# Collecting sklearn_crfsuite
#   Cloning https://github.com/MeMartijn/updated-sklearn-crfsuite.git to c:\users\ewout\appdata\local\temp\pip-install-_9ztzup3\sklearn-crfsuite_b0b40f71e6e14b42b4bbec547440c5db
#   Resolved https://github.com/MeMartijn/updated-sklearn-crfsuite.git to commit 675038761b4405f04691a83339d04903790e2b95
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: tqdm>=2.0 in c:\users\ewout\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from sklearn_crfsuite) (4.62.3)
# Requirement already satisfied: six in c:\users\ewout\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from sklearn_crfsuite) (1.12.0)
# Requirement already satisfied: tabulate in c:\users\ewout\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from sklearn_crfsuite) (0.9.0)
# Requirement already satisfied: python-crfsuite>=0.8.3 in c:\users\ewout\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from sklearn_crfsuite) (0.9.8)
# Requirement already satisfied: colorama in c:\users\ewout\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tqdm>=2.0->sklearn_crfsuite) (0.4.4)
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone --filter=blob:none --quiet https://github.com/MeMartijn/updated-sklearn-crfsuite.git 'C:\Users\ewout\AppData\Local\Temp\pip-install-_9ztzup3\sklearn-crfsuite_b0b40f71e6e14b42b4bbec547440c5db'
#
# [notice] A new release of pip is available: 23.0 -> 23.0.1
# [notice] To update, run: C:\Users\ewout\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: scikit_learn in c:\users\ewout\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (1.1.3)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\ewout\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from scikit_learn) (1.0.1)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\ewout\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from scikit_learn) (1.8.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\ewout\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from scikit_learn) (3.1.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\ewout\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from scikit_learn) (1.21.4)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0 -> 23.0.1
# [notice] To update, run: C:\Users\ewout\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: nltk in c:\users\ewout\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (3.6.5)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\ewout\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from nltk) (2021.9.24)
# Requirement already satisfied: click in c:\users\ewout\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from nltk) (8.0.1)
# Requirement already satisfied: tqdm in c:\users\ewout\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from nltk) (4.62.3)
# Requirement already satisfied: joblib in c:\users\ewout\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from nltk) (1.0.1)
# Requirement already satisfied: colorama in c:\users\ewout\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from click->nltk) (0.4.4)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0 -> 23.0.1
# [notice] To update, run: C:\Users\ewout\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: seaborn in c:\users\ewout\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (0.12.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\ewout\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from seaborn) (3.5.1)
# Requirement already satisfied: pandas>=0.25 in c:\users\ewout\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from seaborn) (1.4.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\ewout\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from seaborn) (1.21.4)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\ewout\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ewout\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ewout\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (8.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ewout\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.31.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\ewout\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\ewout\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ewout\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ewout\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas>=0.25->seaborn) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\ewout\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.12.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0 -> 23.0.1
# [notice] To update, run: C:\Users\ewout\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# import required libraries
import pandas as pd 
import nltk
import sklearn
import scipy.stats
import numpy as np
import seaborn as sns
import sklearn_crfsuite

#from matplotlib 
from matplotlib import pyplot as plt

#from itertools
from itertools import chain

#from sklearn
from sklearn import svm
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import make_scorer
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import train_test_split
from sklearn_crfsuite import scorers
from sklearn_crfsuite import metrics

# %%
#load the data and ontologies

# %%
#this function turns the file into a list. 
def file2list(fileLocation):
    outputList = []
    with open(fileLocation, 'r', encoding='utf8') as myfile:
        sentences = myfile.read().split('\n\n')
        for sentence in sentences:
                sentenceList = []
                words = sentence.split('\n')
                for word in words:
                    wordsList = []
                    attributes = word.split(' ')
                    for attribute in attributes:
                        wordsList.append(attribute)
                    sentenceList.append(wordsList)
                outputList.append(sentenceList)
    
    return outputList

# %%
# train =  file2list('D:\\phd-data\\NER-annotation-data\\Dutch\\5-folds-with-pos-with-cut-sentences\\fold1.txt') 
# test =  file2list('D:\\phd-data\\NER-annotation-data\\Dutch\\5-folds-with-pos-with-cut-sentences\\fold2.txt')

#load the datasets, with training documents as train, and test documents and test
fold = "fold1"
train =  file2list('data/5-folds-test-train-split/' + fold + '/train.txt') 
test =  file2list('data/5-folds-test-train-split/' + fold + '/test.txt')

#remove empty line at the end of the file as this breaks the code
test.pop() 
train.pop()
# Out:
# [['']]

# %%
# %%time 
# calculates the time to open the file
        
#train the NER on the list. there is one set of test and one of training. often 20:80 split
train_sent = train
test_sent = test   # tests the sent (input) of the given list as defined above
train_sent[0] # displayes the first 10 rows in the bio. - each row hs the token (effectively word), followed by pos?, and the bio label
# Out:
# CPU times: total: 31.2 ms
# Wall time: 32 ms
# [['1', 'NUM', 'O'], ['.', 'PUNCT', 'O']]

# %%
#time to load the ontologies 
"""
#artifact ontology
artifacts = pd.read_csv(r'ontologies\artifacts.csv') #open the file
artifacts[artifacts.columns[2]]= artifacts[artifacts.columns[2]].str.lower() #takes the second column (the one with the entities) and makes it all lower case
artifacts_list = artifacts[artifacts.columns[2]].values.tolist() #turns the items into a list
print(artifacts_list) # outputs the list of terms to see what sort of data it contains
print("\n""\n")
"""
artifacts_list = []
with open(r"ontologies\german_mobile_objects.txt", "r", encoding="utf-8") as f:
    for i in f:
        artifacts_list.append(i.strip('\n'))
print(artifacts_list[0:100])
print("\n\n")
"""

#Taxon ontology
# taxon = pd.read_csv(r'ontologies\Taxon.tsv', sep="\t", error_bad_lines=False) #open the file
# taxon[taxon.columns[8]]= taxon[taxon.columns[8]].str.lower() #takes the second column (the one with the entities) and makes it all lower case
# taxon_list = taxon[taxon.columns[8]].values.tolist() #turns the items into a list
# print(taxon_list[0:100]) # outputs the list of terms to see what sort of data it contains
# print("\n""\n")

#Animal ontology
animal = pd.read_csv(r'ontologies\VernacularName.tsv', sep="\t") #open the file
animal[animal.columns[2]]= animal[animal.columns[2]].str.lower() #takes the second column (the one with the entities) and makes it all lower case
animal_list = animal[animal.columns[2]].values.tolist() #turns the items into a list
print(animal_list[0:100]) # outputs the list of terms to see what sort of data it contains
print("\n""\n")
"""

#Periods ontology - for notes see above
#periods = pd.read_csv(r'ontologies\Periods.csv')
#periods[periods.columns[1]]= periods[periods.columns[1]].str.lower()
#periods_list = periods[periods.columns[1]].values.tolist()
periods_list = []
with open(r"ontologies\periodo-dataset.txt", "r", encoding="utf-8") as f:
    for i in f:
        periods_list.append(i.strip('\n'))
print(periods_list[0:100])
print("\n\n")

#Context ontology - for notes see artifact 
"""
context = pd.read_csv(r'ontologies\context.csv')
context[context.columns[0]]= context[context.columns[0]].str.lower().str.replace('*','').str.replace('<','').str.replace('>','') #replace all other symbols
context[context.columns[0]]= context[context.columns[0]].replace(to_replace =':.*',value='',regex=True) # replace the words after a colon
context_list = context[context.columns[0]].values.tolist()
print(context_list[0:100])
print("\n""\n")
"""
# Out:
# ['Pflüge', 'Bögen', 'Haartracht', 'Feuerstellen', 'Dämpfer', 'mechanische Waffen', 'Truhen', 'Mörser', 'Prüfsteine', 'Abschlaggeräte', 'Kopfbedeckungen', 'Webstühle', 'Dechsel', 'Goldblechkegel', 'Webgewichte', 'Peitschen', 'Pectorale', 'Siegelkapseln', 'Siegel', 'Bänke', 'Mauerkronen', 'Tische', 'Phaleren', 'Helme', 'Himatia', 'Speerspitzen', 'Bänder', 'Reliquien', 'Dolche', 'Särge', 'Kämme', 'Diapositive', 'Klappstühle', 'Galeri', 'Kreuze', 'Taufbecken', 'Benefiziarier-Abzeichen', 'Herde', 'Lochstäbe', 'Klopfsteine', 'Hufeisen', 'Angriffswaffen', 'Herrscherornat', 'Exomis', 'Fingerringe', 'Briefe', 'Nadeln', 'Hacken', 'Grabstatuen', 'Waffengürtel', 'Obeloi', 'Dukaten', 'Mensae', 'Netzsenker', 'Statuen', 'Schwerter', 'Halsschmuck', 'Weberschiffchen', 'Wägen', 'Gewichte', 'Stolen', 'Ruder', 'Breitkeile', 'Schleifsteine', 'Fäden', 'Sonden', 'Stelen', 'Opferschalen', 'Beutel', 'Eidolon', 'Ehrenstatuen', 'Beinschmuck', 'Pinsel', 'Wandreliefs', 'Leinwände', 'Trichter', 'Kittel', 'Spangen', 'Messer', 'Rillensteine', 'Streitpickel', 'Staatsreliefs', 'Matrizen', 'Flöten', 'Thyrsosstäbe', 'Diptychen', 'Historische Reliefs', 'Lampen', 'Heroenreliefs', 'Ahlen', 'Schuhe', 'Spottkruzifixe', 'Gesichtshelme', 'Blattspitzen', 'Rednerbühnen', 'Federkronen', 'Wasserfahrzeuge', 'Kouroi', 'Angeln', 'Korai']
#
#
#
# ['Jüngere Eisenzeit', 'Mittel Neolithikum', 'Mittlere Bronzezeit', 'Mittelpaläolithikum', 'Ältere Kupferzeit', 'Mesolithikum', 'Hochmittelalter', 'Zeitgeschichte', 'Älteres Jungpaläolithikum', 'Spätpaläolithikum', 'Frühe Bronzezeit', 'Frühes Neolithikum', 'Mittlere Kupferzeit', 'Zeitgeschichte', 'Mittleres Jungpaläolithikum', 'Eisenzeit', 'Mittelpaläolithikum', 'Römische', 'Frühe Römische', 'Paläolithikum', 'Späte Bronzezeit', 'Späte Römische', 'Mesolithikum', 'Ältere Kupferzeit', 'Neuzeit', 'Frühe Bronzezeit', 'Völkerwanderungszeit', 'Mittel Neolithikum', 'Späte Römische', 'Paläolithikum', 'Späte Bronzezeit', 'Mittelalter', 'Mittelalter', 'Spätmittelalter', 'Frühes Neolithikum', 'Älteres Jungpaläolithikum', 'Neuzeit', 'Frühe Römische', 'Spätpaläolithikum', 'Jüngeres Jungpaläolithikum', 'Jüngeres Jungpaläolithikum', 'Bronzezeit', 'Kupferzeit', 'Hochmittelalter', 'Mittleres Jungpaläolithikum', 'Jüngere Kupferzeit', 'Frühes Mittelalter', 'Frühes Mittelalter', 'Mittlere Kupferzeit', 'Jüngere Kupferzeit', 'Neolithikum', 'Neolithikum', 'Mittlere Bronzezeit', 'Völkerwanderungszeit', 'Eisenzeit', 'Römische', 'Kupferzeit', 'Spätmittelalter', 'Ältere Eisenzeit', 'Bronzezeit', 'Alter Styl', 'Strenger Styl', 'Zweiten Periode', 'Vorgerückten Kunstsitte', 'Chalkolithikum', 'Geometrische Zeit', 'frühgeometrisch', 'mittelgeometrisch', 'spätgeometrisch', 'Archaische Epoche', 'früharchaisch', 'mittelarchaisch', 'spätarchaisch', 'Klassische Epoche', 'Strenger Stil', 'Hochklassik', 'Reicher Stil', 'Spätklassik', 'Hellenistische Epoche', 'frühhellenistisch', 'hochhellenistisch', 'späthellenistisch', 'Früheisenzeit', 'Archaische Zeit', 'Republikanische Zeit', 'frührepublikanisch', 'mittelrepublikanisch', 'spätrepublikanisch', 'Frühe Kaiserzeit', 'Mittlere Kaiserzeit', 'Späte Kaiserzeit', 'Spätantike', 'Frühe Ägäische Bronzezeit I-III', 'Mittlere Ägäische Bronzezeit', 'MM / MH I-II', 'MM / MH III', 'Späte Ägäische Bronzezeit', 'SM I A / SH I', 'SM I B / SH II A', 'SM II / SH II B']
# '\ncontext = pd.read_csv(r\'ontologies\\context.csv\')\ncontext[context.columns[0]]= context[context.columns[0]].str.lower().str.replace(\'*\',\'\').str.replace(\'<\',\'\').str.replace(\'>\',\'\') #replace all other symbols\ncontext[context.columns[0]]= context[context.columns[0]].replace(to_replace =\':.*\',value=\'\',regex=True) # replace the words after a colon\ncontext_list = context[context.columns[0]].values.tolist()\nprint(context_list[0:100])\nprint("\n""\n")\n'

# %%
# turn each word into a list of features
def word2features(sent, i): 
    word = sent[i][0] #this is the token
    postag = sent[i][1] #this is the Part of Speech tag
    
     #this tells if the token is in the ontology or not 
    if word in artifacts_list: 
        in_artifacts = True 
    else:
        in_artifacts = False
    
#     if word in taxon_list: 
#         in_taxon = True 
#     else:
#         in_taxon = False
    
#    if word in animal_list: 
#        in_animal = True 
#    else:
#        in_animal = False
  
    if word in periods_list: 
        in_periods = True 
    else:
        in_periods = False

#    if word in context_list: 
#        in_context = True 
#    else:
#        in_context = False
    
    #time to give each token some information     
    features = { # these are all default. 
        'bias': 1.0, # bias is just 1. 
        'word.lower()': word.lower(), # tells if the token is lower case 
        'word[-3:]': word[-3:], # takes the last four letters - the suffix
        'Word.in_artifacts': in_artifacts, #is the token in the artifact ontology
#         'Word.in_taxon': in_taxon, #is the token in the artifact ontology
#         'Word.in_animal': in_animal, #is the token in the periods ontology 
        'Word.in_periods': in_periods, #is the token in the periods ontology
#        'Word.in_context': in_context, #is the token in the evidence ontology
        'word.isupper()': word.isupper(), # tells if the whole token is uppercase 
        'word.istitle()': word.istitle(), # tells if the token is capital first letter
        'postag': postag,  # what is its label - Part-Of-Speech Tagger
        'postag[:2]': postag[:2],  #Takes the first three letters of the tag
        'word.isdigit()': word.isdigit(),
    }
    if i > 0: #if the token is not at the start of a sentence
        word1 = sent[i-1][0] # works out details of the token before - this is to understand the context 
        postag1 = sent[i-1][1] #what is the postag of the word before
        wordbefore = (sent[i-1][0]+ ' ' +sent[i][0]).lower #this is the token and the token before
        #if this word and word before is in the ontology then 
        if wordbefore in artifacts_list: 
            wordbefore_in_artifacts = True 
        else:
            wordbefore_in_artifacts = False

#         if wordbefore in taxon_list: 
#             wordbefore_in_taxon = True 
#         else:
#             wordbefore_in_taxon = False

#        if wordbefore in animal_list: 
#            wordbefore_in_animal = True 
#            print(word)
#        else:
#            wordbefore_in_animal = False

        if wordbefore in periods_list: 
            wordbefore_in_periods = True 
        else:
            wordbefore_in_periods = False

#        if wordbefore in context_list: 
#            wordbefore_in_context = True 
#        else:
#            wordbefore_in_context = False
        features.update({
            '-1:word.lower()': word1.lower(), # tells if the token is lower case
            '-1:word.istitle()': word1.istitle(), # tells if the token is capital first letter
            '-1:word.isdigit()': word1.isdigit(), # tells if the toekn is only numbers
            '-1:word.isupper()': word1.isupper(),# tells if the whole token is uppercase
            'wordbefore_in_artifacts': wordbefore_in_artifacts,
#             'wordbefore_in_taxon': wordbefore_in_taxon,
#             'wordbefore_in_animal': wordbefore_in_animal,
            'wordbefore_in_periods': wordbefore_in_periods,
#            'wordbefore_in_context': wordbefore_in_context,
            '-1:postag': postag1, # what was its POS tag
            '-1:postag[:2]': postag1[:2], #what is the first three POS tag of the word before
        })
    
        if i > 1: #if the token is not at the start of a sentence
                word3 = sent[i-1][0] # works out details of the token before - this is to understand the context 
                postag3 = sent[i-1][1] #what is the postag of the word before
                two_words_before = (sent[i-1][0]+ ' ' +sent[i-1][0]+ ' ' +sent[i][0]).lower #this is the token and the token before
                #if this word and word before is in the ontology then 
                if two_words_before in artifacts_list: 
                    two_words_before_in_artifacts = True 
                else:
                    two_words_before_in_artifacts = False

#                 if two_words_before in taxon_list: 
#                     two_words_before_in_taxon = True 
#                 else:
#                     two_words_before_in_taxon = False

#                if two_words_before in animal_list: 
#                    two_words_before_in_animal = True 
#                    print(word)
#                else:
#                    two_words_before_in_animal = False

                if two_words_before in periods_list: 
                    two_words_before_in_periods = True 
                else:
                    two_words_before_in_periods = False

#                if two_words_before in context_list: 
#                    two_words_before_in_context = True 
#                else:
#                    two_words_before_in_context = False
                features.update({
                    '-1:word.lower()': word1.lower(), # tells if the token is lower case
                    '-1:word.istitle()': word1.istitle(), # tells if the token is capital first letter
                    '-1:word.isdigit()': word1.isdigit(), # tells if the toekn is only numbers
                    '-1:word.isupper()': word1.isupper(),# tells if the whole token is uppercase
                    'two_words_before_in_artifacts': two_words_before_in_artifacts,
#                     'two_words_before_in_taxon': two_words_before_in_taxon,
#                     'two_words_before_in_animal': two_words_before_in_animal,
                    'two_words_before_in_periods': two_words_before_in_periods,
#                    'two_words_before_in_context': two_words_before_in_context,
                    '-2-postag': postag3, # what was its POS tag
                    '-2:postag[:2]': postag3[:2], #what is the first three POS tag of the word before
                })
        else:
            features['BOS2'] = True # if word is the beggining of sentence label it as so         
    else:
        features['BOS'] = True # if word is the beggining of sentence label it as so 
        
    if i < len(sent)-1: # is the word at the end of the sentence. sme as above after
        wordafter= (sent[i][0]+ ' ' +sent[i+1][0]).lower
        #this tells if the token AFTER and each token combined is in the ontology or not
        if wordafter in artifacts_list: 
            wordafter_in_artifacts = True 
        else:
            wordafter_in_artifacts = False

#         if wordafter in taxon_list: 
#             wordafter_in_taxon = True 
#         else:
#             wordafter_in_taxon = False

#        if wordafter in animal_list: 
#            wordafter_in_animal = True 
#        else:
#            wordafter_in_animal = False

        if wordafter in periods_list: 
            wordafter_in_periods = True 
        else:
            wordafter_in_periods = False

#        if wordafter in context_list: 
#            wordafter_in_context = True 
#        else:
#            wordafter_in_context = False
        word2 = sent[i+1][0]  
        postag2 = sent[i+1][1] 
        features.update({
            'wordafter_in_artifacts': wordafter_in_artifacts,
#             'wordafter_in_taxon': wordafter_in_taxon,
#             'wordafter_in_animal': wordafter_in_animal,
            'wordafter_in_periods': wordafter_in_periods,
#            'wordafter_in_context': wordafter_in_context,
            '+2:word.lower()': word2.lower(),
            '+2:word.istitle()': word2.istitle(),
            '+2:word.isupper()': word2.isupper(),
            '+2:postag': postag2,
            '+2:postag[:2]': postag2[:2],
        })
        
        if i < len(sent)-2: #if the token is not at the start of a sentence
                word4 = sent[i-1][0] # works out details of the token before - this is to understand the context 
                postag4 = sent[i-1][1] #what is the postag of the word before
                two_words_after = (sent[i][0]+ ' ' +sent[i+1][0]+ ' ' +sent[i+1][0]).lower#this is the token and the token before
                #if this word and word before is in the ontology then 
                if two_words_after in artifacts_list: 
                    two_words_after_in_artifacts = True 
                else:
                    two_words_after_in_artifacts = False

#                 if two_words_after in taxon_list: 
#                     two_words_after_in_taxon = True 
#                 else:
#                     two_words_after_in_taxon = False

#                if two_words_after in animal_list: 
#                    two_words_after_in_animal = True 
#                    print(word)
#                else:
#                    two_words_after_in_animal = False

                if two_words_after in periods_list: 
                    two_words_after_in_periods = True 
                else:
                   two_words_after_in_periods = False

#                if two_words_after in context_list: 
#                    two_words_after_in_context = True 
#                else:
#                    two_words_after_in_context = False
                features.update({
                    '-1:word.lower()': word4.lower(), # tells if the token is lower case
                    '-1:word.istitle()': word4.istitle(), # tells if the token is capital first letter
                    '-1:word.isdigit()': word4.isdigit(), # tells if the toekn is only numbers
                    '-1:word.isupper()': word4.isupper(),# tells if the whole token is uppercase
                    'two_words_after_in_artifacts': two_words_after_in_artifacts,
#                     'two_words_after_in_taxon': two_words_after_in_taxon,
#                     'two_words_after_in_animal': two_words_after_in_animal,
                    'two_words_after_in_periods': two_words_after_in_periods,
#                    'two_words_after_in_context': two_words_after_in_context,
                    '-2-postag': postag4, # what was its POS tag
                    '-2:postag[:2]': postag4[:2], #what is the first three POS tag of the word before
                })
        else:
            features['EOS2'] = True # if word is the beggining of sentence label it as so       
        
        
        
    else:
        features['EOS'] = True # if word is the end of sentence label it as so         
   

    if i < len(sent)-1 and i > 0: # is the word at the end of the sentence. sme as above after
            word3 = sent[i+1][0]  
            postag3 = sent[i+1][1] 
            wordsorround = (sent[i-1][0]+ ' ' +sent[i][0]+ ' ' +sent[i+1][0]).lower
            if wordsorround in artifacts_list: 
                wordsorround_in_artifacts = True 
            else:
                wordsorround_in_artifacts = False

#             if wordsorround in taxon_list: 
#                 wordsorround_in_taxon = True 
#             else:
#                 wordsorround_in_taxon = False

#            if wordsorround in animal_list: 
#                wordsorround_in_animal = True 
#            else:
#                wordsorround_in_animal = False

            if wordsorround in periods_list: 
                wordsorround_in_periods = True 
            else:
                wordsorround_in_periods = False

#            if wordsorround in context_list: 
#                wordsorround_in_context = True 
#            else:
#                wordsorround_in_context = False
            features.update({
                'wordsorround_in_artifacts': wordsorround_in_artifacts,
#                 'wordsorround_in_taxon': wordsorround_in_taxon,
#                 'wordsorround_in_animal': wordsorround_in_animal,
                'wordsorround_in_periods': wordsorround_in_periods,
#                'wordsorround_in_context': wordsorround_in_context,
            })
            if i < len(sent)-2 and i > 1: # is the word at the end of the sentence. sme as above after
                word5 = sent[i+1][0]  
                postag5 = sent[i+1][1] 
                twowordsorround = (sent[i-2][0]+ ' ' +sent[i-1][0]+ ' ' +sent[i][0]+ ' ' +sent[i+1][0]+ ' ' +sent[i+2][0]).lower
                if twowordsorround in artifacts_list: 
                    twowordsorround_in_artifacts = True 
                else:
                    twowordsorround_in_artifacts = False

#                 if twowordsorround in taxon_list: 
#                     twowordsorround_in_taxon = True 
#                 else:
#                     twowordsorround_in_taxon = False

#                if twowordsorround in animal_list: 
#                    twowordsorround_in_animal = True 
#                else:
#                    twowordsorround_in_animal = False

                if twowordsorround in periods_list: 
                    twowordsorround_in_periods = True 
                else:
                    twowordsorround_in_periods = False

#                if twowordsorround in context_list: 
#                    twowordsorround_in_context = True 
#                else:
#                    twowordsorround_in_context = False
                features.update({
                    'twowordsorround_in_artifacts': twowordsorround_in_artifacts,
#                     'twowordsorround_in_taxon': twowordsorround_in_taxon,
#                     'twowordsorround_in_animal': twowordsorround_in_animal,
                    'twowordsorround_in_periods': twowordsorround_in_periods,
#                    'twowordsorround_in_context': twowordsorround_in_context,                   
                })
            else:
                    features['OWS'] = True # if word is the end of sentence label it as so 
    else:
            features['OWS'] = True # if word is the end of sentence label it as so 
            
    return features # output these details
def sent2features(sent):
    return [word2features(sent, i) for i in range(len(sent))] #output for each word

def sent2labels(sent):
    #print(sent)
    for word in sent:
        if len(word) > 3:
            print(word)
    return [label for token, postag, label in sent] #output for each token

def sent2tokens(sent):
    return [token for token, postag, label in sent] #output for ???

# %%
#print(sent2features[:2])

# %%
#sent2features(train_sent[0:1])[0]
[sent2features(s) for s in train_sent[0:1]]
# Out:
# [[{'bias': 1.0,
#    'word.lower()': '1',
#    'word[-3:]': '1',
#    'Word.in_artifacts': False,
#    'Word.in_periods': False,
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'postag': 'NUM',
#    'postag[:2]': 'NU',
#    'word.isdigit()': True,
#    'BOS': True,
#    'wordafter_in_artifacts': False,
#    'wordafter_in_periods': False,
#    '+2:word.lower()': '.',
#    '+2:word.istitle()': False,
#    '+2:word.isupper()': False,
#    '+2:postag': 'PUNCT',
#    '+2:postag[:2]': 'PU',
#    'EOS2': True,
#    'OWS': True},
#   {'bias': 1.0,
#    'word.lower()': '.',
#    'word[-3:]': '.',
#    'Word.in_artifacts': False,
#    'Word.in_periods': False,
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'postag': 'PUNCT',
#    'postag[:2]': 'PU',
#    'word.isdigit()': False,
#    '-1:word.lower()': '1',
#    '-1:word.istitle()': False,
#    '-1:word.isdigit()': True,
#    '-1:word.isupper()': False,
#    'wordbefore_in_artifacts': False,
#    'wordbefore_in_periods': False,
#    '-1:postag': 'NUM',
#    '-1:postag[:2]': 'NU',
#    'BOS2': True,
#    'EOS': True,
#    'OWS': True}]]

# %%
#time to train the NER

# %%
# %%time
X_train = [sent2features(s) for s in train_sent] # for the token train the ner on the learned set
y_train = [sent2labels(s) for s in train_sent] # for the POS tag train the ner on the learned set
# Out:
# CPU times: total: 10.7 s
# Wall time: 11 s

# %%
X_test = [sent2features(s) for s in test_sent] # for the token train the ner on the test set
y_test = [sent2labels(s) for s in test_sent] # for the POS tag train the ner on the test set

# %%
# %%time
crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs', 
    c1=0.1,  
    c2=0.1, 
    max_iterations=100, 
    all_possible_transitions=True
)
#crf.fit(X_train, y_train)
try:
    crf.fit(X_train, y_train)
except AttributeError:
    pass
# Out:
# CPU times: total: 36.7 s
# Wall time: 37.7 s

# %%
labels = list(crf.classes_) # get the list of all labels
labels.remove('O') # remove the ones where bio is o - not got a postag
labels # show what the labels are
# Out:
# ['B-PER',
#  'B-LOC',
#  'I-PER',
#  'I-LOC',
#  'B-ART',
#  'I-ART',
#  'B-MAT',
#  'B-CON',
#  'I-CON',
#  'B-SPE',
#  'I-SPE',
#  'I-MAT']

# %%
#now to evaluate its success

# %%
#calculate the f1 score
y_pred = crf.predict(X_test) # work out and predict what is the likely token
metrics.flat_f1_score(y_test, y_pred, # work out what the likely postag will be, and give it a f1 score
                      average='weighted', labels=labels)
# Out:
# 0.47936727087168934

# %%
#calculate the metrics table
# group B and I results - this isnt needed, but orders the list
sorted_labels = sorted(
    labels, 
    key=lambda name: (name[1:], name[0])
)
#print(metrics.classification_report(y_test, y_pred))
print(metrics.flat_classification_report(
    y_test, y_pred, labels=sorted_labels
))
with open ("classification report "+ fold +".txt", 'w', encoding="utf-8") as f:
    f.write(metrics.flat_classification_report(
    y_test, y_pred, labels=sorted_labels
))
# Out:
# C:\Users\ewout\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ewout\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ewout\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ewout\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#        B-ART       0.69      0.32      0.43       720
#        I-ART       0.24      0.12      0.16       155
#        B-CON       0.84      0.45      0.59      1113
#        I-CON       0.06      0.01      0.02       177
#        B-LOC       0.63      0.20      0.30       567
#        I-LOC       0.44      0.10      0.16       168
#        B-MAT       0.94      0.17      0.28       173
#        I-MAT       0.00      0.00      0.00         9
#        B-PER       0.89      0.50      0.64      1255
#        I-PER       0.70      0.43      0.53       633
#        B-SPE       0.62      0.42      0.50        24
#        I-SPE       0.00      0.00      0.00         1
#
#    micro avg       0.76      0.36      0.49      4995
#    macro avg       0.50      0.23      0.30      4995
# weighted avg       0.73      0.36      0.48      4995
# C:\Users\ewout\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ewout\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
output = "Word  actual_tag  prediction"
for x in range(len(test_sent)):
    for i in range(len(test_sent[x])):
        testWord = test_sent[x][i][0]
        testTag = test_sent[x][i][2]
        prediction = y_pred[x][i]
        output += "\n" + testWord + "  " + testTag + "  " + prediction
        #print(testWord + "," + testTag + "," + prediction)
    output += "\n"
with open ("prediction output "+ fold +".txt", 'w', encoding="utf-8") as f:
    f.write(output)
print(output)
# Out:
# Word  actual_tag  prediction
# Einleitung  O  O
# Der  O  O
# ursprüngliche  O  O
# Entstehungskontext  O  O
# eines  O  O
# archäologischen  O  O
# Befunds  O  O
# und  O  O
# der  O  O
# in  O  O
# ihm  O  O
# fassbaren  O  O
# Objekte  O  O
# spielt  O  O
# eine  O  O
# primäre  O  O
# Rolle  O  O
# für  O  O
# die  O  O
# Interpretation  O  O
# materieller  O  O
# Hinterlassenschaften  O  O
# .  O  O
#
# Gräber  B-CON  B-CON
# stellen  O  O
# in  O  O
# erster  O  O
# Linie  O  O
# das  O  O
# Resultat  O  O
# eines  O  O
# sozial  O  O
# prekären  O  O
# und  O  O
# emotionalen  O  O
# Ereignisses  O  O
# in  O  O
# einer  O  O
# Gemeinschaft  O  O
# dar  O  O
# –  O  O
# dem  O  O
# Tod  O  O
# eines  O  O
# ihrer  O  O
# Mitglieder  O  O
# .  O  O
#
# Aus  O  O
# archäologischer  O  O
# Perspektive  O  O
# repräsentieren  O  O
# Bestattungen  B-CON  B-CON
# so  O  O
# eine  O  O
# primäre  O  O
# Quelle  O  O
# für  O  O
# die  O  O
# Erforschung  O  O
# des  O  O
# Todesverständnisses  O  O
# in  O  O
# vergangenen  O  O
# Gesellschaften  O  O
# .  O  O
#
# In  O  O
# der  O  O
# deutschsprachigen  O  O
# Frühmittelalterforschung  O  O
# standen  O  O
# bislang  O  O
# materialbasierte  O  O
# Arbeiten  O  O
# ,  O  O
# die  O  O
# sich  O  O
# der  O  O
# typochronologischen  O  O
# Auswertung  O  O
# von  O  O
# Grabinventaren  B-CON  O
# (  O  O
# z.B.  O  O
# Böhner  O  O
# 1958  B-PER  B-PER
# ;  O  O
# Koch  O  O
# 1977  B-PER  B-PER
# ;  O  O
# Menghin  O  O
# 1983  B-PER  B-PER
# ;  O  O
# Strauß  O  O
# 1992  B-PER  B-PER
# ;  O  O
# Theune  O  O
# 1999a  O  O
# ;  O  O
# Schach-Dörges  O  O
# 2004  B-PER  B-PER
# ;  O  O
# Schwarz  O  O
# 2004  B-PER  B-PER
# )  O  O
# ,  O  O
# der  O  O
# Frage  O  O
# nach  O  O
# dem  O  O
# Ausdruck  O  O
# ethnischer  O  O
# Identitäten  O  O
# (  O  O
# z.B.  O  O
# Siegmann  O  O
# 2002–2005  B-PER  O
# ;  O  O
# Brather  O  O
# und  O  O
# Wotzka  O  O
# 2006  B-PER  B-PER
# ;  O  O
# Theune  O  O
# 2008  B-PER  B-PER
# )  O  O
# und  O  O
# der  O  O
# Rekonstruktion  O  O
# von  O  O
# Gesellschaftsstrukturen  O  O
# (  O  O
# z.B.  O  O
# Veeck  O  O
# 1926  B-PER  O
# ;  O  O
# Christlein  O  O
# 1968  B-PER  B-PER
# ;  O  O
# Steuer  O  O
# 1968  B-PER  B-PER
# ;  O  O
# 2004  B-PER  B-PER
# ;  O  O
# Stauch  O  O
# 2012  B-PER  B-PER
# )  O  O
# anhand  O  O
# der  O  O
# zahlreichen  O  O
# merowingerzeitlichen  B-PER  O
# Gräberfelder  B-CON  O
# widmeten  O  O
# ,  O  O
# im  O  O
# Zentrum  O  O
# des  O  O
# Interesses  O  O
# .  O  O
#
# Studien  O  O
# zu  O  O
# Glaubensvorstellungen  O  O
# und  O  O
# religiösen  O  O
# Aspekten  O  O
# im  O  O
# merowingerzeitlichen  B-PER  O
# Bestattungsbrauchtum  O  O
# befassen  O  O
# sich  O  O
# v.a  O  O
# .  O  O
#
# mit  O  O
# der  O  O
# Christianisierung  O  O
# im  O  O
# Sinne  O  O
# eines  O  O
# Bekenntniswechsels  O  O
# aus  O  O
# historischer  O  O
# Perspektive  O  O
# (  O  O
# z.B.  O  O
# Berschin  O  O
# ,  O  O
# Geuenich  O  O
# und  O  O
# Steuer  O  O
# 2000  B-PER  B-PER
# ;  O  O
# Lorenz  O  O
# und  O  O
# Scholkmann  O  O
# 2003  B-PER  B-PER
# ;  O  O
# Heinrich-Tamáska  O  O
# ,  O  O
# Krohn  O  B-SPE
# und  O  O
# Ristow  O  O
# 2012  B-PER  B-PER
# )  O  O
# ,  O  O
# wobei  O  O
# eine  O  O
# objektbasierte  O  O
# Forschung  O  O
# dominiert  O  O
# (  O  O
# Schülke  O  O
# 1997  B-PER  B-PER
# ;  O  O
# z.B.  O  O
# Knaut  O  O
# 2003  B-PER  B-PER
# )  O  O
# .  O  O
#
# Die  O  O
# Untersuchung  O  O
# dieser  O  O
# historischen  O  O
# Prozesse  O  O
# beleuchtet  O  O
# aber  O  O
# nur  O  O
# bedingt  O  O
# die  O  O
# tatsächliche  O  O
# Beziehung  O  O
# der  O  O
# frühmittelalterlichen  B-PER  O
# Menschen  O  B-SPE
# zum  O  O
# Tod  O  O
# ,  O  O
# da  O  O
# sie  O  O
# sich  O  O
# mehr  O  O
# mit  O  O
# der  O  O
# offiziellen  O  O
# Konfessionszugehörigkeit  O  O
# als  O  O
# den  O  O
# dahinterstehenden  O  O
# Ontologien  O  O
# und  O  O
# damit  O  O
# zusammenhängenden  O  O
# sozialen  O  O
# Praktiken  O  O
# auseinandersetzt  O  O
# .  O  O
#
# Auch  O  O
# im  O  O
# theoretischen  O  O
# Diskurs  O  O
# der  O  O
# anglophonen  O  O
# Forschung  O  O
# lag  O  O
# und  O  O
# liegt  O  O
# das  O  O
# Hauptaugenmerk  O  O
# der  O  O
# Bestattungsarchäologie  O  O
# auf  O  O
# der  O  O
# Dynamik  O  O
# sozialer  O  O
# Strukturen  O  O
# ,  O  O
# wobei  O  O
# sich  O  O
# die  O  O
# Diskussion  O  O
# weg  O  O
# von  O  O
# den  O  O
# funktionalistischen  O  O
# Ansätzen  O  O
# der  O  O
# Prozessualen  O  O
# Archäologie  O  O
# ,  O  O
# hin  O  O
# zur  O  O
# Frage  O  O
# nach  O  O
# dem  O  O
# Zusammenspiel  O  O
# menschlicher  O  O
# und  O  O
# nichtmenschlicher  O  O
# Akteure  O  O
# in  O  O
# sozialen  O  O
# Netzwerken  O  O
# ,  O  O
# Identitätsbildungsprozessen  O  O
# und  O  O
# materielle  O  O
# Kultur  O  O
# ,  O  O
# Erinnerungskultur  O  O
# sowie  O  O
# menschlichem  O  O
# Körperverständnis  O  O
# verschoben  O  O
# hat  O  O
# (  O  O
# z.B.  O  O
# Díaz-Andreu  O  O
# et  O  O
# al  O  O
# .  O  O
#
# 2005  B-PER  B-PER
# ;  O  O
# Williams  O  O
# 2006  B-PER  B-PER
# ;  O  O
# Boric  O  O
# und  O  O
# Robb  O  O
# 2008  B-PER  B-PER
# ;  O  O
# Rebay-Salisbury  O  O
# ,  O  O
# Sørensen  O  O
# und  O  O
# Hughes  O  O
# 2010  B-PER  B-PER
# ;  O  O
# Tarlow  O  O
# und  O  O
# Nilsson  O  O
# Stutz  O  O
# 2013  B-PER  B-PER
# )  O  O
# .  O  O
#
# Gräber  B-CON  B-CON
# als  O  O
# materielle  O  O
# Manifestation  O  O
# eines  O  O
# Bewältigungskonzeptes  O  O
# der  O  O
# Todesproblematik  O  O
# zu  O  O
# betrachten  O  O
# und  O  O
# als  O  O
# Quelle  O  O
# einer  O  O
# Untersuchung  O  O
# zur  O  O
# Einstellung  O  O
# einer  O  O
# Gesellschaft  O  O
# zu  O  O
# Sterben  O  O
# und  O  O
# Tod  O  O
# zu  O  O
# verstehen  O  O
# ,  O  O
# stellen  O  O
# im  O  O
# Rahmen  O  O
# der  O  O
# eben  O  O
# besprochenen  O  O
# Themen  O  O
# eine  O  O
# noch  O  O
# sehr  O  O
# junge  O  O
# Forschungsagenda  O  O
# dar  O  O
# (  O  O
# z.B.  O  O
# Taylor  O  O
# 2008  B-PER  B-PER
# )  O  O
# und  O  O
# haben  O  O
# in  O  O
# materialbasierten  O  O
# Studien  O  O
# bisher  O  O
# nur  O  O
# wenig  O  O
# Beachtung  O  O
# gefunden  O  O
# (  O  O
# z.B.  O  O
# Carr  O  O
# 1995  B-PER  B-PER
# ;  O  O
# Hofmann  O  O
# 2008  B-PER  B-PER
# ;  O  O
# Rebay-Salisbury  O  O
# 2012  B-PER  B-PER
# )  O  O
# .  O  O
#
# Die  O  O
# vorliegende  O  O
# Studie  O  O
# setzt  O  O
# an  O  O
# diesem  O  O
# Forschungsdesiderat  O  O
# an  O  O
# und  O  O
# befasst  O  O
# sich  O  O
# mit  O  O
# der  O  O
# Einstellung  O  O
# und  O  O
# den  O  O
# Vorstellungen  O  O
# der  O  O
# merowingerzeitlichen  B-PER  O
# Bevölkerung  O  O
# zum  O  O
# Tod  O  O
# am  O  O
# Beispiel  O  O
# der  O  O
# Gräberfelder  B-CON  O
# von  O  O
# Bad  B-LOC  O
# Mingolsheim  I-LOC  O
# (  O  O
# Landkreis  O  O
# Karlsruhe  B-LOC  O
# )  O  O
# ,  O  O
# Horb-Altheim  B-LOC  B-LOC
# (  O  O
# Landkreis  O  O
# Freudenstadt  B-LOC  B-LOC
# )  O  O
# und  O  O
# Weingarten  B-LOC  O
# (  O  O
# Landkreis  O  O
# Ravensburg  B-LOC  B-LOC
# )  O  O
# ,  O  O
# die  O  O
# alle  O  O
# auf  O  O
# dem  O  O
# geografischen  O  O
# Gebiet  O  O
# der  O  O
# frühmittelalterlichen  B-PER  O
# 10  O  O
# am  O  O
# rande  O  O
# des  O  O
# grabs  B-CON  O
# Alamannia  B-LOC  O
# bzw.  O  O
# des  O  O
# heutigen  O  O
# Südwestdeutschland  B-LOC  O
# liegen1  O  O
# .  O  O
#
# Im  O  O
# Zentrum  O  O
# steht  O  O
# die  O  O
# Frage  O  O
# ,  O  O
# ob  O  O
# sich  O  O
# durch  O  O
# den  O  O
# systematischen  O  O
# Vergleich  O  O
# archäologischer  O  O
# und  O  O
# anthropologischer  O  O
# Daten  O  O
# Aspekte  O  O
# in  O  O
# der  O  O
# rituellen  O  O
# Praxis  O  O
# dieser  O  O
# Gemeinschaften  O  O
# differenzieren  O  O
# lassen  O  O
# ,  O  O
# die  O  O
# eher  O  O
# auf  O  O
# die  O  O
# Lebendgesellschaft  O  O
# oder  O  O
# auf  O  O
# ontologisch  O  O
# bedingte  O  O
# Konzepte  O  O
# von  O  O
# Folgewelten  O  O
# und  O  O
# Totenidentitäten  O  O
# bezogen  O  O
# werden  O  O
# können  O  O
# .  O  O
#
# Durch  O  O
# die  O  O
# Gegenüberstellung  O  O
# von  O  O
# humananthropologischen  O  O
# Indikatoren  O  O
# für  O  O
# die  O  O
# alltäglichen  O  O
# Tätigkeiten  O  O
# der  O  O
# untersuchten  O  O
# Gemeinschaften  O  O
# sowie  O  O
# paläopathologischer  O  O
# Daten  O  O
# mit  O  O
# der  O  O
# Darstellung  O  O
# der  O  O
# Toten  O  O
# im  O  O
# Grab  B-CON  B-CON
# wird  O  O
# das  O  O
# Zusammenspiel  O  O
# von  O  O
# Todesumständen  O  O
# ,  O  O
# Lebensidentitäten  O  O
# und  O  O
# Glaubensvorstellung  O  O
# bei  O  O
# der  O  O
# Grabgestaltung  O  O
# untersucht  O  O
# und  O  O
# so  O  O
# ein  O  O
# alternativer  O  O
# Blickwinkel  O  O
# auf  O  O
# die  O  O
# komplexen  O  O
# Dynamiken  O  O
# der  O  O
# frühmittelalterlichen  B-PER  O
# Gesellschaft  O  O
# und  O  O
# ihrer  O  O
# Beziehung  O  O
# zu  O  O
# den  O  O
# Toten  O  O
# angestrebt  O  O
# ,  O  O
# welcher  O  O
# den  O  O
# Entstehungskontext  O  O
# dieser  O  O
# archäologischen  O  O
# Hinterlassenschaften  O  O
# stärker  O  O
# berücksichtigen  O  O
# soll  O  O
# .  O  O
#
# Die  O  O
# Arbeit  O  O
# gliedert  O  O
# sich  O  O
# in  O  O
# acht  O  O
# Abschnitte  O  O
# und  O  O
# beginnt  O  O
# mit  O  O
# einem  O  O
# einleitenden  O  O
# Überblick  O  O
# (  O  O
# Kapitel  O  O
# 1  O  O
# )  O  O
# ,  O  O
# welcher  O  O
# einen  O  O
# forschungsgeschichtlichen  O  O
# Abriss  O  O
# zur  O  O
# frühmittelalterlichen  B-PER  O
# Gräberfeldarchäologie  O  O
# mit  O  O
# Fokus  O  O
# auf  O  O
# die  O  O
# merowingerzeitliche  B-PER  O
# Alamannia  B-LOC  O
# enthält  O  O
# .  O  O
#
# Zusätzlich  O  O
# wird  O  O
# die  O  O
# Entwicklung  O  O
# in  O  O
# der  O  O
# anglophonen  O  O
# Theoriediskussion  O  O
# zur  O  O
# Bestattungsarchäologie  O  O
# besprochen  O  O
# und  O  O
# so  O  O
# ein  O  O
# breites  O  O
# Spektrum  O  O
# unterschiedlicher  O  O
# Ansätze  O  O
# und  O  O
# Interpretationsmodelle  O  O
# für  O  O
# Bestattungen  B-CON  B-CON
# präsentiert  O  O
# .  O  O
#
# Diese  O  O
# Ausführungen  O  O
# münden  O  O
# in  O  O
# der  O  O
# Erhebung  O  O
# gegenwärtiger  O  O
# Forschungstrends  O  O
# im  O  O
# Fach  O  O
# sowie  O  O
# der  O  O
# Definition  O  O
# von  O  O
# Forschungsdesideraten  O  O
# und  O  O
# leiten  O  O
# zum  O  O
# nächsten  O  O
# Kapitel  O  O
# über  O  O
# ,  O  O
# in  O  O
# welchem  O  O
# der  O  O
# theoretische  O  O
# Rahmen  O  O
# der  O  O
# Studie  O  O
# vorgestellt  O  O
# wird  O  O
# .  O  O
#
# Kapitel  O  O
# 2  O  O
# befasst  O  O
# sich  O  O
# zunächst  O  O
# mit  O  O
# philosophischen  O  O
# ,  O  O
# kulturanthropologischen  O  O
# ,  O  O
# soziologischen  O  O
# und  O  O
# historischen  O  O
# Studien  O  O
# zum  O  O
# menschlichen  O  O
# Todesverständnis  O  O
# und  O  O
# dem  O  O
# kulturellen  O  O
# Umgang  O  O
# mit  O  O
# dem  O  O
# Tod  O  O
# (  O  O
# u.a.  O  O
# Hertz  O  O
# 1907  B-PER  O
# ;  O  O
# Huntington  O  O
# und  O  O
# Metcalf  O  O
# 1979  B-PER  B-PER
# ;  O  O
# Ariés  O  O
# 1981  B-PER  B-PER
# ;  O  O
# Feldmann  O  O
# 1990  B-PER  B-PER
# ;  O  O
# Van  O  O
# Gennep  O  O
# 1909  B-PER  O
# ;  O  O
# Jankélévitch  O  O
# 2005  B-PER  B-PER
# )  O  O
# ,  O  O
# um  O  O
# so  O  O
# eine  O  O
# Sensibilität  O  O
# für  O  O
# den  O  O
# Fokus  O  O
# dieser  O  O
# Arbeit  O  O
# zu  O  O
# schaffen  O  O
# und  O  O
# Modelle  O  O
# aus  O  O
# den  O  O
# Nachbardisziplinen  O  O
# ,  O  O
# die  O  O
# sich  O  O
# für  O  O
# die  O  O
# Analyse  O  O
# frühmittelalterlicher  B-PER  O
# Bestattungen  B-CON  B-CON
# eignen  O  O
# ,  O  O
# vorzustellen  O  O
# (  O  O
# z.B.  O  O
# Enninger  O  O
# und  O  O
# Schwens  O  O
# 1989  B-PER  B-PER
# ;  O  O
# Härke  O  O
# 2003  B-PER  B-PER
# ;  O  O
# Seale  O  O
# und  O  O
# van  O  O
# der  O  O
# Geest  O  O
# 2004  B-PER  B-PER
# ;  O  O
# Hockey  O  O
# und  O  O
# Draper  O  O
# 2005  B-PER  B-PER
# )  O  O
# .  O  O
#
# Dabei  O  O
# werden  O  O
# der  O  O
# Stellenwert  O  O
# thanatoarchäologischer  O  O
# Fragestellungen  O  O
# (  O  O
# sensu  O  O
# Hofmann  O  O
# 2008  B-PER  O
# :  O  O
# Kap  O  O
# .  O  O
#
# VII  O  O
# )  O  O
# in  O  O
# der  O  O
# gegenwärtigen  O  O
# Diskussion  O  O
# zum  O  O
# Einfluss  O  O
# von  O  O
# Glaubensvorstellungen  O  O
# und  O  O
# Religionsbekenntnissen  O  O
# in  O  O
# der  O  O
# deutschsprachigen  O  O
# Frühmittelalterforschung  O  O
# kritisch  O  O
# diskutiert  O  O
# und  O  O
# anschließend  O  O
# die  O  O
# Forschungsziele  O  O
# dieser  O  O
# Studie  O  O
# formuliert  O  O
# ,  O  O
# die  O  O
# auf  O  O
# eine  O  O
# Analyse  O  O
# der  O  O
# Einstellung  O  O
# zum  O  O
# und  O  O
# der  O  O
# Vorstellung  O  O
# vom  O  O
# Tod  O  O
# in  O  O
# der  O  O
# frühmittelalterlichen  B-PER  O
# Gesellschaft  O  O
# gerichtet  O  O
# ist  O  O
# .  O  O
#
# Im  O  O
# anschließenden  O  O
# Kapitel  O  O
# 3  O  O
# werden  O  O
# die  O  O
# als  O  O
# Fallstudien  O  O
# ausgewählten  O  O
# Gräberfelder  B-CON  O
# von  O  O
# Bad  B-LOC  O
# Mingolsheim  I-LOC  O
# (  O  O
# vgl.  O  O
# Schäfer  O  O
# 2005  B-PER  B-PER
# )  O  O
# ,  O  O
# Horb-Altheim  B-LOC  B-LOC
# (  O  O
# vgl.  O  O
# Beilharz  O  O
# 2011  B-PER  B-PER
# )  O  O
# und  O  O
# Weingarten  B-LOC  O
# (  O  O
# vgl.  O  O
# Roth  O  O
# und  O  O
# Theune  O  O
# 1995  B-PER  B-PER
# ;  O  O
# Theune  O  O
# im  O  O
# Druck  O  O
# )  O  O
# vorgestellt  O  O
# und  O  O
# deren  O  O
# zeitliche  O  O
# und  O  O
# räumliche  O  O
# Verortung  O  O
# dargelegt  O  O
# .  O  O
#
# Die  O  O
# Auswahl  O  O
# der  O  O
# Fundstellen  O  O
# erfolgte  O  O
# auf  O  O
# Basis  O  O
# des  O  O
# guten  O  O
# Publikationsstands  O  O
# .  O  O
#
# In  O  O
# allen  O  O
# Fällen  O  O
# sind  O  O
# die  O  O
# Materialvorlagen  O  O
# bzw.  O  O
# typochronologische  O  O
# Auswertungen  O  O
# sowie  O  O
# zusätzliche  O  O
# naturwissenschaftliche  O  O
# Untersuchungen  O  O
# der  O  O
# menschlichen  B-SPE  B-SPE
# Skelette  B-ART  B-ART
# bereits  O  O
# verfügbar  O  O
# ,  O  O
# sodass  O  O
# die  O  O
# drei  O  O
# Gräberfelder  B-CON  O
# die  O  O
# erforderliche  O  O
# umfangreiche  O  O
# Datengrundlage  O  O
# aufweisen  O  O
# .  O  O
#
# 1  O  O
# Vgl.  O  O
# für  O  O
# eine  O  O
# umfassende  O  O
# Darstellung  O  O
# der  O  O
# frühmittelalterlichen  B-PER  O
# Bodenfunde  O  O
# dieses  O  O
# Gebiets  O  O
# Theune  O  O
# 2004.  O  O
# einleitung  O  O
# 11  O  O
# Zur  O  O
# Untersuchung  O  O
# der  O  O
# relevanten  O  O
# Fragestellungen  O  O
# wurde  O  O
# für  O  O
# jedes  O  O
# Gräberfeld  B-CON  B-CON
# ein  O  O
# systematischer  O  O
# Vergleich  O  O
# archäologischer  O  O
# Daten  O  O
# zu  O  O
# Grabinventaren  O  O
# (  O  O
# Inventardaten  O  O
# )  O  O
# und  O  O
# Grabgestaltung  O  O
# (  O  O
# Ritualdaten  O  O
# )  O  O
# mit  O  O
# anthropologischen  O  O
# Informationen  O  O
# zu  O  O
# Alter  O  O
# ,  O  O
# Geschlecht  O  O
# ,  O  O
# Verwandtschaft  O  O
# ,  O  O
# Provenienz  O  O
# und  O  O
# Pathologien  O  O
# in  O  O
# den  O  O
# Bestattungsgemeinschaften  O  O
# durchgeführt  O  O
# .  O  O
#
# Als  O  O
# Basis  O  O
# diente  O  O
# hierzu  O  O
# die  O  O
# auf  O  O
# Clusteranalysen  O  O
# basierende  O  O
# Methode  O  O
# der  O  O
# Contextual  O  O
# Statistical  O  O
# Analysis  O  O
# nach  O  O
# C.  O  O
# N.  O  O
# Popa  O  O
# (  O  O
# 2012  O  B-PER
# ;  O  O
# 2014  O  B-PER
# )  O  O
# ,  O  O
# welche  O  O
# speziell  O  O
# auf  O  O
# die  O  O
# statistische  O  O
# Auswertung  O  O
# mehrdimensionaler  O  O
# Datensätze  O  O
# aus  O  O
# Bestattungen  B-CON  B-CON
# ausgerichtet  O  O
# ist  O  O
# .  O  O
#
# Die  O  O
# Funktionsweise  O  O
# der  O  O
# Methode  O  O
# wird  O  O
# ausführlich  O  O
# in  O  O
# Kapitel  O  O
# 4  O  O
# besprochen  O  O
# .  O  O
#
# Begleitet  O  O
# sind  O  O
# diese  O  O
# Erläuterungen  O  O
# einerseits  O  O
# von  O  O
# einer  O  O
# kritischen  O  O
# Reflexion  O  O
# zur  O  O
# Verwendung  O  O
# statistischer  O  O
# Verfahren  O  O
# in  O  O
# der  O  O
# Archäologie  O  O
# und  O  O
# andererseits  O  O
# von  O  O
# einer  O  O
# detaillierten  O  O
# Beschreibung  O  O
# der  O  O
# Datenaufnahme  O  O
# und  O  O
# -strukturierung  O  O
# ,  O  O
# welche  O  O
# besonders  O  O
# in  O  O
# Hinblick  O  O
# auf  O  O
# die  O  O
# zuvor  O  O
# definierten  O  O
# Fragestellungen  O  O
# entwickelt  O  O
# und  O  O
# durchgeführt  O  O
# wurde  O  O
# .  O  O
#
# Das  O  O
# Kernstück  O  O
# dieser  O  O
# Studie  O  O
# bildet  O  O
# die  O  O
# Auswertung  O  O
# und  O  O
# Interpretation  O  O
# der  O  O
# Gräberfelder  B-CON  O
# von  O  O
# Bad  B-LOC  O
# Mingolsheim  I-LOC  O
# ,  O  O
# Horb-Altheim  B-LOC  B-LOC
# und  O  O
# Weingarten  B-LOC  O
# .  O  O
#
# Da  O  O
# jede  O  O
# der  O  O
# Fallstudien  O  O
# separat  O  O
# untersucht  O  O
# wurde  O  O
# ,  O  O
# werden  O  O
# auch  O  O
# die  O  O
# Ergebnisse  O  O
# getrennt  O  O
# in  O  O
# den  O  O
# Kapiteln  O  O
# 5  O  O
# bis  O  O
# 7  O  O
# vorgestellt  O  O
# .  O  O
#
# Für  O  O
# jeden  O  O
# Bestattungsplatz  B-CON  O
# wird  O  O
# zunächst  O  O
# die  O  O
# archäologische  O  O
# Konstitutionsgrundlage  O  O
# der  O  O
# Clusteranalysen  O  O
# besprochen  O  O
# und  O  O
# mit  O  O
# den  O  O
# anthropologischen  O  O
# Parametern  O  O
# verglichen  O  O
# .  O  O
#
# Auf  O  O
# Basis  O  O
# der  O  O
# erkannten  O  O
# Muster  O  O
# erfolgt  O  O
# dann  O  O
# die  O  O
# Verknüpfung  O  O
# der  O  O
# Resultate  O  O
# mit  O  O
# den  O  O
# theoretischen  O  O
# Überlegungen  O  O
# ,  O  O
# wobei  O  O
# die  O  O
# Frage  O  O
# nach  O  O
# der  O  O
# Relation  O  O
# von  O  O
# Konstruktion  O  O
# der  O  O
# Totenidentität  O  O
# des  O  O
# Verstorbenen2  O  O
# im  O  O
# Grab  B-CON  B-CON
# und  O  O
# seinen  O  O
# sozialen  O  O
# Rollen  O  O
# im  O  O
# Leben  O  O
# diskutiert  O  O
# ,  O  O
# Mechanismen  O  O
# und  O  O
# Einflüsse  O  O
# diesseits-  O  O
# und  O  O
# jenseitsbezogener  O  O
# Aspekte  O  O
# im  O  O
# Bestattungsritual  O  O
# differenziert  O  O
# und  O  O
# Grundstrukturen  O  O
# gemeinschaftlicher  O  O
# Todeskonzepte  O  O
# herausgearbeitet  O  O
# werden  O  O
# .  O  O
#
# Die  O  O
# Details  O  O
# der  O  O
# statistischen  O  O
# Auswertungen  O  O
# sind  O  O
# in  O  O
# detaillierten  O  O
# Tabellen  O  O
# im  O  O
# digitalen  O  O
# Annex  O  O
# der  O  O
# Arbeit  O  O
# dargestellt  O  O
# ,  O  O
# der  O  O
# uneingeschränkt  O  O
# und  O  O
# kostenlos  O  O
# von  O  O
# KOPS  O  O
# (  O  O
# Online-Repository  O  O
# der  O  O
# Universität  O  O
# Konstanz  B-LOC  O
# :  O  O
# http  O  O
# :  O  O
# //nbn-resolving.de/urn  O  O
# :  O  O
# nbn  O  O
# :  O  O
# de  O  O
# :  O  O
# bsz:352-0-283673  O  O
# )  O  O
# heruntergeladen  O  O
# werden  O  O
# kann  O  O
# .  O  O
#
# Im  O  O
# Kapitel  O  O
# 8  O  O
# werden  O  O
# die  O  O
# Ergebnisse  O  O
# der  O  O
# Fallstudien  O  O
# einander  O  O
# gegenübergestellt  O  O
# und  O  O
# Unterschiede  O  O
# und  O  O
# Ähnlichkeiten  O  O
# in  O  O
# den  O  O
# einzelnen  O  O
# Gemeinschaften  O  O
# ,  O  O
# eingebettet  O  O
# in  O  O
# ihren  O  O
# spezifischen  O  O
# historischen  O  O
# Kontext  O  O
# ,  O  O
# diskutiert  O  O
# .  O  O
#
# Abschließend  O  O
# wird  O  O
# in  O  O
# einem  O  O
# Resümee  O  O
# der  O  O
# Stellenwert  O  O
# der  O  O
# gewonnenen  O  O
# Erkenntnisse  O  O
# für  O  O
# die  O  O
# Frühmittelalterforschung  O  O
# besprochen  O  O
# und  O  O
# ein  O  O
# Ausblick  O  O
# auf  O  O
# die  O  O
# künftige  O  O
# Untersuchung  O  O
# merowingerzeitlicher  B-PER  O
# Bestattungsrituale  O  O
# gegeben  O  O
# .  O  O
#
# 2  O  O
# Aus  O  O
# Gründen  O  O
# der  O  O
# Lesbarkeit  O  O
# des  O  O
# Texts  O  O
# wird  O  O
# bei  O  O
# Aussagen  O  O
# ,  O  O
# die  O  O
# allgemein  O  O
# zu  O  O
# verstehen  O  O
# sind  O  O
# und  O  O
# beide  O  O
# Geschlechter  O  O
# betreffen  O  O
# ,  O  O
# die  O  O
# maskuline  O  O
# Form  O  O
# verwendet  O  O
# und  O  O
# ist  O  O
# in  O  O
# diesem  O  O
# Sinne  O  O
# als  O  O
# geschlechtsneutral  O  O
# zu  O  O
# verstehen  O  O
# .  O  O
#
# Feminina  O  O
# sind  O  O
# Sachverhalten  O  O
# vorbehalten  O  O
# ,  O  O
# die  O  O
# ausdrücklich  O  O
# das  O  O
# weibliche  O  O
# Geschlecht  O  O
# ,  O  O
# sowohl  O  O
# im  O  O
# biologischen  O  O
# als  O  O
# auch  O  O
# im  O  O
# sozialen  O  O
# Sinne  O  O
# ,  O  O
# betreffen  O  O
# .  O  O
#
# die  O  O
# archäologie  O  O
# und  O  O
# der  O  O
# tod  O  O
# –  O  O
# überblick  O  O
# zur  O  O
# forschungsgeschichte  O  O
# 13  O  O
# Kapitel  O  O
# 1  O  O
# Die  O  O
# Archäologie  O  O
# und  O  O
# der  O  O
# Tod  O  O
# –  O  O
# Überblick  O  O
# zur  O  O
# Forschungsgeschichte  O  O
# Da  O  O
# sich  O  O
# diese  O  O
# Arbeit  O  O
# als  O  O
# theoretisch  O  O
# fundierte  O  O
# Materialanalyse  O  O
# versteht  O  O
# ,  O  O
# wird  O  O
# in  O  O
# diesem  O  O
# Kapitel  O  O
# zunächst  O  O
# ein  O  O
# Überblick  O  O
# über  O  O
# die  O  O
# Forschungsgeschichte  O  O
# und  O  O
# Interpretationsmodelle  O  O
# zu  O  O
# Bestattungen  O  B-CON
# in  O  O
# der  O  O
# deutschsprachigen  O  O
# Frühmittelalterarchäologie  O  O
# Südwestdeutschlands  B-LOC  B-LOC
# gegeben  O  O
# ,  O  O
# in  O  O
# welche  O  O
# sich  O  O
# die  O  O
# vorliegende  O  O
# Studie  O  O
# zeitlich  O  O
# und  O  O
# geografisch  O  O
# einreiht  O  O
# ,  O  O
# und  O  O
# anschließend  O  O
# die  O  O
# Entwicklung  O  O
# theoretischer  O  O
# Debatten  O  O
# zur  O  O
# Bedeutung  O  O
# von  O  O
# Bestattungen  B-CON  B-CON
# in  O  O
# der  O  O
# Archäologie  O  O
# skizziert  O  O
# .  O  O
#
# Auf  O  O
# eine  O  O
# Diskussion  O  O
# bezüglich  O  O
# chronologischer  O  O
# Studien  O  O
# anhand  O  O
# frühmittelalterlicher  B-PER  B-CON
# Bestattungen  B-CON  I-CON
# wird  O  O
# hingegen  O  O
# verzichtet  O  O
# ,  O  O
# da  O  O
# in  O  O
# dieser  O  O
# Untersuchung  O  O
# kulturanthropologische  O  O
# Aspekte  O  O
# im  O  O
# Vordergrund  O  O
# stehen  O  O
# und  O  O
# dementsprechend  O  O
# auch  O  O
# der  O  O
# Fokus  O  O
# des  O  O
# forschungsgeschichtlichen  O  O
# Überblicks  O  O
# auf  O  O
# den  O  O
# bisherigen  O  O
# Interpretationsansätzen  O  O
# liegt  O  O
# .  O  O
#
# An  O  O
# dieser  O  O
# Stelle  O  O
# sei  O  O
# aber  O  O
# auf  O  O
# den  O  O
# fundamentalen  O  O
# Stellenwert  O  O
# chronologischer  O  O
# Untersuchungen  O  O
# ,  O  O
# besonders  O  O
# in  O  O
# der  O  O
# deutschsprachigen  O  O
# Frühmittelalterforschung  O  O
# verwiesen  O  O
# ,  O  O
# der  O  O
# ,  O  O
# eingebettet  O  O
# in  O  O
# einen  O  O
# eigenständigen  O  O
# ,  O  O
# theoretischen  O  O
# und  O  O
# methodischen  O  O
# Diskurs  O  O
# ,  O  O
# den  O  O
# zeitlichen  O  O
# Bezugsrahmen  O  O
# für  O  O
# jegliche  O  O
# archäologische  O  O
# Untersuchung  O  O
# bedingt  O  O
# und  O  O
# somit  O  O
# eine  O  O
# Voraussetzung  O  O
# für  O  O
# eine  O  O
# fundierte  O  O
# Interpretation  O  O
# darstellt  O  O
# (  O  O
# vgl.  O  O
# Steuer  O  O
# 1998  O  B-PER
# )  O  O
# 3  O  O
# .  O  O
#
# 1.1  O  O
# Gräberfeldarchäologie  O  O
# der  O  O
# Merowingerzeit  B-PER  B-PER
# in  O  O
# Südwestdeutschland  B-LOC  O
# Die  O  O
# deutschsprachige  O  O
# Frühmittelalterarchäologie  O  O
# hat  O  O
# seit  O  O
# ihrer  O  O
# Konstitution  O  O
# als  O  O
# Wissenschaft  O  O
# vor  O  O
# etwa  O  O
# 100  O  O
# Jahren  O  O
# die  O  O
# Untersuchung  O  O
# von  O  O
# Bestattungen  B-CON  B-CON
# zu  O  O
# einem  O  O
# zentralen  O  O
# Interessengebiet  O  O
# ihrer  O  O
# Forschung  O  O
# erklärt  O  O
# .  O  O
#
# Neben  O  O
# den  O  O
# umfangreichen  O  O
# chronologischen  O  O
# Studien  O  O
# an  O  O
# merowingerzeitlichen  B-CON  O
# Grabbeigaben4  O  O
# aus  O  O
# den  O  O
# zahlreichen  O  O
# Gräberfeldern  B-CON  O
# der  O  O
# ehemaligen  O  O
# Frankia  B-LOC  O
# ,  O  O
# Alamannia  B-LOC  O
# und  O  O
# Baiuvaria  B-LOC  O
# ,  O  O
# konzentrieren  O  O
# sich  O  O
# Interpretationen  O  O
# zur  O  O
# Bedeutung  O  O
# und  O  O
# Aussage  O  O
# dieser  O  O
# materiellen  O  O
# 3  O  O
# Für  O  O
# relevante  O  O
# Studien  O  O
# zur  O  O
# Chronologie  O  O
# merowingerzeitlicher  B-PER  O
# Bestattungen  O  B-CON
# siehe  O  O
# u.a.  O  O
# :  O  O
# Werner  O  O
# 1935  B-PER  O
# ;  O  O
# Böhner  O  O
# 1958  B-PER  B-PER
# ;  O  O
# Ament  O  O
# 1977  B-PER  B-PER
# ;  O  O
# Roth  O  O
# und  O  O
# Theune  O  O
# 1988  B-PER  B-PER
# ;  O  O
# Martin  O  O
# 1989  B-PER  B-PER
# ;  O  O
# Sasse  O  O
# und  O  O
# Theune  O  O
# 1996  B-PER  B-PER
# ;  O  O
# Siegmund  O  O
# 1998  B-PER  B-PER
# ;  O  O
# Wernard  O  O
# 1998  B-PER  B-PER
# ;  O  O
# Theune  O  O
# 2001  B-PER  B-PER
# ;  O  O
# Müssemeier  O  O
# et  O  O
# al  O  O
# .  O  O
#
# 2003  B-PER  B-PER
# .  O  O
#
# 4  O  O
# Sensu  O  O
# Härke  O  O
# 2003  B-PER  B-PER
# .  O  O
#
# Da  O  O
# alle  O  O
# in  O  O
# einer  O  O
# Bestattung  B-CON  B-CON
# inszenierten  O  O
# Objekte  O  O
# –  O  O
# auch  O  O
# Kleidungsaccessoires  B-ART  O
# –  O  O
# bewusst  O  O
# für  O  O
# die  O  O
# Beisetzung  B-CON  O
# ausgewählt  O  O
# wurden  O  O
# und  O  O
# im  O  O
# Frühmittelalter  B-PER  O
# eine  O  O
# Konkordanz  O  O
# zwischen  O  O
# dem  O  O
# Verschwinden  O  O
# „  O  O
# echter  O  O
# Beigaben  O  O
# “  O  O
# ,  O  O
# „  O  O
# Trachtbestandteilen  B-ART  O
# “  O  O
# oder  O  O
# anderen  O  O
# Kategorien  O  O
# von  O  O
# Grabfunden  B-CON  O
# (  O  O
# vgl.  O  O
# zu  O  O
# unterschiedlichen  O  O
# Kategorisierungen  O  O
# Hachmann  O  O
# und  O  O
# Penner  O  O
# 1999  B-PER  B-PER
# )  O  O
# besteht  O  O
# ,  O  O
# kann  O  O
# laut  O  O
# H.  O  O
# Härke  O  O
# ein  O  O
# analytischer  O  O
# Unterschied  O  O
# zwischen  O  O
# „  O  O
# Beigabe  O  O
# “  O  O
# und  O  O
# etwa  O  O
# „  O  O
# Kleidungsaccessoires  B-ART  O
# “  O  O
# nicht  O  O
# sicher  O  O
# getroffen  O  O
# werden  O  O
# ,  O  O
# da  O  O
# nicht  O  O
# klar  O  O
# ist  O  O
# ,  O  O
# ob  O  O
# die  O  O
# Betroffenen  O  O
# tatsächlich  O  O
# verschiedene  O  O
# Kategorien  O  O
# mit  O  O
# diesen  O  O
# unterschiedlichen  O  O
# Gegenständen  O  O
# verbanden  O  O
# .  O  O
#
# Hier  O  O
# besteht  O  O
# v.a  O  O
# .  O  O
#
# auch  O  O
# ein  O  O
# Problem  O  O
# der  O  O
# Erschließung  O  O
# unterschiedlicher  O  O
# semiotischer  O  O
# Ebenen  O  O
# für  O  O
# die  O  O
# Intention  O  O
# der  O  O
# Mitgabe  O  O
# bestimmter  O  O
# Objekte  O  O
# (  O  O
# Kümmel  O  O
# 2008  B-PER  O
# :  O  O
# 476  O  O
# )  O  O
# .  O  O
#
# Daher  O  O
# sind  O  O
# in  O  O
# der  O  O
# vorliegenden  O  O
# Arbeit  O  O
# unter  O  O
# dem  O  O
# Begriff  O  O
# „  O  O
# Beigaben  O  O
# “  O  O
# alle  O  O
# dem  O  O
# Toten  O  O
# am  O  O
# Körper  O  O
# oder  O  O
# in  O  O
# die  O  O
# Grabgrube  B-CON  O
# mitgegebenen  O  O
# Artefakte  O  O
# zu  O  O
# verstehen  O  O
# ,  O  O
# wobei  O  O
# mit  O  O
# diesem  O  O
# Terminus  O  O
# keine  O  O
# Aussage  O  O
# über  O  O
# die  O  O
# Intentionen  O  O
# getroffen  O  O
# wird  O  O
# ,  O  O
# welche  O  O
# hinter  O  O
# der  O  O
# Mitgabe  O  O
# dieser  O  O
# Objekte  O  O
# standen  O  O
# .  O  O
#
# 14  O  O
# am  O  O
# rande  O  O
# des  O  O
# grabs  B-CON  O
# Hinterlassenschaften  O  O
# des  O  O
# Totenbrauchtums  O  O
# überwiegend  O  O
# auf  O  O
# die  O  O
# Analyse  O  O
# der  O  O
# Sozialstrukturen  O  O
# frühmittelalterlicher  B-PER  O
# Gemeinschaften  O  O
# und  O  O
# die  O  O
# Frage  O  O
# nach  O  O
# der  O  O
# Manifestation  O  O
# ethnischer  O  O
# Identitäten  O  O
# (  O  O
# z.B.  O  O
# Martin  O  O
# 2002  B-PER  B-PER
# ;  O  O
# Brather  O  O
# 2008  B-PER  B-PER
# )  O  O
# .  O  O
#
# Diese  O  O
# Debatten  O  O
# erfolgen  O  O
# vornehmlich  O  O
# in  O  O
# einem  O  O
# kulturhistorischen  O  O
# Rahmen  O  O
# und  O  O
# basieren  O  O
# v.a  O  O
# .  O  O
#
# auf  O  O
# sehr  O  O
# detailreichen  O  O
# Materialanalysen  O  O
# und  O  O
# in  O  O
# jüngerer  O  O
# Zeit  O  O
# auch  O  O
# auf  O  O
# vermehrter  O  O
# Kooperation  O  O
# mit  O  O
# den  O  O
# Naturwissenschaften  O  O
# ,  O  O
# woraus  O  O
# sich  O  O
# bedeutende  O  O
# Erkenntnisse  O  O
# zu  O  O
# demografischen  O  O
# Verhältnissen  O  O
# und  O  O
# ehemaligen  O  O
# Lebenswelten  O  O
# ergeben  O  O
# haben  O  O
# ,  O  O
# die  O  O
# zu  O  O
# einer  O  O
# Verbreiterung  O  O
# unseres  O  O
# kulturgeschichtlichen  O  O
# Verständnisses  O  O
# beitragen  O  O
# .  O  O
#
# Im  O  O
# Fach  O  O
# ist  O  O
# allerdings  O  O
# nach  O  O
# wie  O  O
# vor  O  O
# eine  O  O
# gewisse  O  O
# Zurückhaltung  O  O
# gegenüber  O  O
# theoretischen  O  O
# Debatten  O  O
# zum  O  O
# Zustandekommen  O  O
# der  O  O
# diskutierten  O  O
# Interpretationen  O  O
# immanent  O  O
# (  O  O
# vgl.  O  O
# hierzu  O  O
# Härke  O  O
# 2000  B-PER  B-PER
# ;  O  O
# Gramsch  O  O
# 2011  B-PER  B-PER
# )  O  O
# .  O  O
#
# Kapitel  O  O
# 3  O  O
# Untersuchte  O  O
# Gräberfelder  B-CON  O
# im  O  O
# Überblick  O  O
# Für  O  O
# die  O  O
# Untersuchung  O  O
# der  O  O
# vorgestellten  O  O
# Fragestellungen  O  O
# wurden  O  O
# drei  O  O
# Gräberfelder  B-CON  O
# auf  O  O
# dem  O  O
# Gebiet  O  O
# der  O  O
# frühmittelalterlichen  B-PER  O
# Alamannia  B-LOC  O
# bzw.  O  O
# dem  O  O
# heutigen  O  O
# Baden-  B-LOC  O
# Württemberg  I-LOC  O
# ausgewählt  O  O
# ,  O  O
# die  O  O
# ein  O  O
# breites  O  O
# Spektrum  O  O
# an  O  O
# Datenmaterial  O  O
# aufweisen  O  O
# :  O  O
# Bad  B-LOC  O
# Mingolsheim  I-LOC  O
# (  O  O
# Landkreis  O  O
# Karlsruhe  B-LOC  O
# )  O  O
# ,  O  O
# Horb-Altheim  B-LOC  B-LOC
# (  O  O
# Landkreis  O  O
# Freudenstadt  B-LOC  B-LOC
# )  O  O
# und  O  O
# Weingarten  B-LOC  O
# (  O  O
# Landkreis  O  O
# Ravensburg  B-LOC  B-LOC
# )  O  O
# (  O  O
# Abb  O  O
# .  O  O
#
# 3.1  O  O
# )  O  O
# .  O  O
#
# In  O  O
# allen  O  O
# drei  O  O
# Fällen  O  O
# liegen  O  O
# bereits  O  O
# typochronologische  O  O
# Auswertungen  O  O
# des  O  O
# archäologischen  O  O
# Materials  O  O
# und  O  O
# anthropologische  O  O
# Bestimmungen  O  O
# zu  O  O
# Alter  O  O
# und  O  O
# Geschlecht  O  O
# der  O  O
# menschlichen  B-SPE  B-SPE
# Überreste  O  O
# vor  O  O
# .  O  O
#
# Hinzu  O  O
# kommen  O  O
# für  O  O
# die  O  O
# Gräberfelder  B-CON  O
# von  O  O
# Bad  B-LOC  B-LOC
# Mingolsheim  I-LOC  I-LOC
# und  O  O
# Horb-Altheim  B-LOC  O
# paläopathologische  O  O
# Untersuchungen  O  O
# ,  O  O
# 87SR/86SR-Analysen  O  O
# an  O  O
# den  O  O
# Skeletten  B-ART  O
# von  O  O
# Horb-Altheim  B-LOC  B-LOC
# und  O  O
# Weingarten  B-LOC  O
# sowie  O  O
# Untersuchungen  O  O
# alter  O  O
# DNA  O  O
# am  O  O
# Sample  O  O
# des  O  O
# letztgenannten  O  O
# Gräberfeldes40  O  O
# .  O  O
#
# Durch  O  O
# die  O  O
# Laufzeiten  O  O
# der  O  O
# einzelnen  O  O
# Bestattungsplätze  B-CON  B-CON
# sind  O  O
# auch  O  O
# chronologische  O  O
# Überschneidungen  O  O
# gegeben  O  O
# ,  O  O
# welche  O  O
# einen  O  O
# weiteren  O  O
# Vergleich  O  O
# der  O  O
# beobachteten  O  O
# archäologischen  O  O
# Muster  O  O
# in  O  O
# den  O  O
# Bestattungsgemeinschaften  O  O
# erlauben  O  O
# .  O  O
#
# Das  O  O
# Gräberfeld  B-CON  B-CON
# von  O  O
# Horb-Altheim  B-LOC  O
# läuft  O  O
# absolutchronologisch  O  O
# ca  O  O
# .  O  O
#
# von  O  O
# der  O  O
# Mitte  B-PER  B-PER
# des  I-PER  I-PER
# 5.  I-PER  I-PER
# bis  I-PER  I-PER
# ins  I-PER  I-PER
# zweite  I-PER  I-PER
# Viertel  I-PER  I-PER
# des  I-PER  I-PER
# 6.  I-PER  I-PER
# Jahrhunderts  I-PER  I-PER
# ,  O  O
# Bad  B-LOC  O
# Mingolsheim  I-LOC  O
# vom  O  O
# letzten  B-PER  O
# Viertel  I-PER  O
# des  I-PER  O
# 6.  I-PER  O
# bis  O  O
# ins  O  O
# letzte  B-PER  O
# Viertel  I-PER  O
# des  I-PER  O
# 7.  I-PER  O
# Jahrhunderts  I-PER  O
# ,  O  O
# Weingarten  B-LOC  O
# vom  O  O
# späten  B-PER  O
# 5.  I-PER  O
# bis  I-PER  O
# in  I-PER  O
# das  I-PER  O
# frühe  I-PER  B-PER
# 8.  I-PER  I-PER
# Jahrhundert  I-PER  I-PER
# n.  I-PER  I-PER
# Chr  I-PER  I-PER
# .  O  I-PER
#
# Dadurch  O  O
# ergibt  O  O
# sich  O  O
# für  O  O
# Horb-Altheim  B-LOC  B-LOC
# eine  O  O
# Überschneidung  O  O
# mit  O  O
# den  O  O
# frühen  O  O
# Belegungsphasen  O  O
# in  O  O
# Weingarten  B-LOC  O
# (  O  O
# KP1–2  O  O
# )  O  O
# 41  O  O
# ,  O  O
# während  O  O
# Bad  B-LOC  O
# Mingolsheim  I-LOC  O
# in  O  O
# etwa  O  O
# parallel  O  O
# zu  O  O
# den  O  O
# jüngeren  O  O
# Phasen  O  O
# von  O  O
# Weingarten  B-LOC  O
# (  O  O
# KP3–4  O  O
# )  O  O
# verläuft  O  O
# .  O  O
#
# 3.1  O  O
# Bad  B-LOC  O
# Mingolsheim  I-LOC  O
# Das  O  O
# Gräberfeld  B-CON  B-CON
# von  O  O
# Bad  B-LOC  O
# Mingolsheim  I-LOC  O
# wurde  O  O
# in  O  O
# den  O  O
# späten  B-PER  B-PER
# 1980er  I-PER  I-PER
# Jahren  I-PER  I-PER
# bei  O  O
# Bauarbeiten  O  O
# entdeckt  O  O
# und  O  O
# mit  O  O
# Unterbrechungen  O  O
# bis  O  O
# 1993  B-PER  B-PER
# ausgegraben  O  O
# .  O  O
#
# Eine  O  O
# zugehörige  O  O
# Siedlung  B-CON  B-CON
# ist  O  O
# nicht  O  O
# bekannt  O  O
# (  O  O
# Banghard  O  O
# 1993  B-PER  B-PER
# ;  O  O
# Schäfer  O  O
# 2005  B-PER  O
# :  O  O
# 417  O  O
# )  O  O
# .  O  O
#
# Bad  B-LOC  O
# Mingolsheim  I-LOC  O
# ist  O  O
# ein  O  O
# Ortsteil  O  O
# der  O  O
# Gemeinde  O  O
# Bad  B-LOC  B-LOC
# Schönborn  I-LOC  I-LOC
# im  O  O
# Landkreis  O  O
# Karlsruhe  B-LOC  O
# und  O  O
# liegt  O  O
# im  O  O
# Nordwesten  O  O
# Baden  B-LOC  O
# Württembergs  I-LOC  O
# ,  O  O
# am  O  O
# Übergang  O  O
# der  O  O
# oberrheinischen  B-LOC  O
# Tiefebene  I-LOC  O
# zum  O  O
# Kraichgauer  B-LOC  O
# Hügelland  I-LOC  O
# .  O  O
#
# Die  O  O
# Fundstelle  O  O
# des  O  O
# Gräberfeldes  B-CON  O
# befindet  O  O
# sich  O  O
# auf  O  O
# einem  O  O
# Hügelausläufer  O  O
# des  O  O
# Kraichgaus  B-LOC  O
# ,  O  O
# leicht  O  O
# oberhalb  O  O
# des  O  O
# Kraichbaches  O  O
# (  O  O
# Schäfer  O  O
# 2005  B-PER  O
# :  O  O
# 320–322  O  O
# )  O  O
# .  O  O
#
# 40  O  O
# Die  O  O
# Dichte  O  O
# frühmittelalterlicher  B-PER  B-CON
# Gräberfelder  B-CON  I-CON
# im  O  O
# Raum  O  O
# der  O  O
# Alamannia  B-LOC  O
# ist  O  O
# enorm  O  O
# und  O  O
# Materialvorlagen  O  O
# sind  O  O
# in  O  O
# großem  O  O
# Umfang  O  O
# vorhanden  O  O
# .  O  O
#
# Ein  O  O
# Großteil  O  O
# dieser  O  O
# Fundorte  O  O
# wurde  O  O
# auch  O  O
# anthropologisch  O  O
# auf  O  O
# biologisches  O  O
# Alter  O  O
# und  O  O
# Geschlecht  O  O
# der  O  O
# Bestattungspopulationen  O  O
# untersucht  O  O
# .  O  O
#
# Weitere  O  O
# naturwissenschaftliche  O  O
# Untersuchungen  O  O
# an  O  O
# den  O  O
# Skeletten  B-ART  O
# ,  O  O
# wie  O  O
# pathologische  O  O
# Analysen  O  O
# ,  O  O
# Strontium-Isotopen-Analysen  O  O
# oder  O  O
# Untersuchungen  O  O
# alter  O  O
# DNA  O  O
# sind  O  O
# verhältnismäßig  O  O
# jedoch  O  O
# nur  O  O
# selten  O  O
# vorhanden  O  O
# .  O  O
#
# 41  O  O
# Zum  O  O
# Chronologiesystem  O  O
# der  O  O
# „  O  O
# Kleiderphasen  O  O
# “  O  O
# (  O  O
# KP  O  O
# )  O  O
# siehe  O  O
# Döhrer  O  O
# 2011  B-PER  B-PER
# :  O  O
# 50-55  O  O
# .  O  O
#
# 60  O  O
# am  O  O
# rande  O  O
# des  O  O
# grabs  B-CON  O
# Die  O  O
# archäologische  O  O
# Auswertung  O  O
# des  O  O
# Materials  O  O
# von  O  O
# Bad  B-LOC  O
# Mingolsheim  I-LOC  O
# wurde  O  O
# von  O  O
# M.  O  O
# Schäfer  O  O
# (  O  O
# 2005  B-PER  B-PER
# ;  O  O
# siehe  O  O
# ebenso  O  O
# Schäfer  O  O
# 2000  B-PER  O
# und  O  O
# 2001  B-PER  B-PER
# )  O  O
# vorgelegt  O  O
# .  O  O
#
# Die  O  O
# Altersund  O  O
# Geschlechtsbestimmung  O  O
# der  O  O
# menschlichen  B-SPE  B-SPE
# Überreste  O  O
# sowie  O  O
# die  O  O
# Aufnahme  O  O
# pathologischer  O  O
# Veränderungen  O  O
# am  O  O
# Skelettmaterial  B-MAT  O
# wurden  O  O
# von  O  O
# A.  O  O
# Czarnetzki  O  O
# (  O  O
# 2005  O  B-PER
# )  O  O
# durchgeführt  O  O
# .  O  O
#
# Insgesamt  O  O
# wurden  O  O
# im  O  O
# Gräberfeld  B-CON  O
# 61  O  O
# Grabgruben  B-CON  O
# dokumentiert42  O  O
# ,  O  O
# in  O  O
# denen  O  O
# 67  O  O
# Individuen  O  O
# bestattet  O  O
# waren43  O  O
# .  O  O
#
# Beim  O  O
# Großteil  O  O
# der  O  O
# Gräber  B-CON  B-CON
# handelte  O  O
# es  O  O
# sich  O  O
# um  O  O
# Einzelbestattungen  B-CON  B-CON
# .  O  O
#
# Mehrfachbestattungen  B-CON  O
# lagen  O  O
# in  O  O
# 13  O  O
# Fällen  O  O
# vor  O  O
# (  O  O
# Schäfer  O  O
# 2005  B-PER  O
# :  O  O
# 324  O  O
# ,  O  O
# 328–330  O  O
# )  O  O
# .  O  O
#
# Grab  O  B-CON
# BM03444  O  O
# stellt  O  O
# den  O  O
# einzigen  O  O
# Verdachtsfall  O  O
# in  O  O
# der  O  O
# vorliegenden  O  O
# Arbeit  O  O
# dar  O  O
# ,  O  O
# bei  O  O
# dem  O  O
# es  O  O
# sich  O  O
# um  O  O
# eine  O  O
# Brand-  O  O
# und  O  O
# keine  O  O
# Körperbestattung  B-CON  O
# gehandelt  O  O
# haben  O  O
# könnte  O  O
# .  O  O
#
# Die  O  O
# nur  O  O
# wenigen  O  O
# vorhandenen  O  O
# Knochenfragmente  B-ART  B-ART
# dieser  O  O
# Bestattung  B-CON  O
# 42  O  O
# Während  O  O
# der  O  O
# Grabung  O  O
# waren  O  O
# 64  O  O
# Befunden  O  O
# als  O  O
# Grabgruben  B-CON  B-CON
# verzeichnet  O  O
# worden  O  O
# .  O  O
#
# Allerdings  O  O
# fallen  O  O
# die  O  O
# Befunde  O  O
# mit  O  O
# den  O  O
# Nummern  O  O
# 9  O  O
# ,  O  O
# 27  O  O
# ,  O  O
# 36  O  O
# und  O  O
# 56  O  O
# weg  O  O
# ,  O  O
# da  O  O
# es  O  O
# sich  O  O
# in  O  O
# diesen  O  O
# Fällen  O  O
# um  O  O
# jüngere  O  O
# Grubenstrukturen  B-CON  O
# handelt  O  O
# ,  O  O
# die  O  O
# in  O  O
# keinem  O  O
# Bezug  O  O
# zum  O  O
# Gräberfeld  B-CON  B-CON
# stehen  O  O
# (  O  O
# Schäfer  O  O
# 2005  B-PER  O
# :  O  O
# 323f  O  O
# .  O  O
# )  O  O
# .  O  O
#
# 43  O  O
# A.  O  O
# Czarnetzki  O  O
# (  O  O
# 2005  B-PER  B-PER
# :  O  O
# 547  O  O
# )  O  O
# identifizierte  O  O
# bei  O  O
# der  O  O
# anthropologischen  O  O
# Auswertung  O  O
# 71  O  O
# Individuen  O  O
# .  O  O
#
# In  O  O
# vier  O  O
# Fällen  O  O
# handelt  O  O
# es  O  O
# sich  O  O
# aber  O  O
# um  O  O
# verlagertes  O  B-ART
# Knochenmaterial  B-MAT  I-ART
# ,  O  O
# bei  O  O
# dem  O  O
# nicht  O  O
# entschieden  O  O
# werden  O  O
# kann  O  O
# ,  O  O
# in  O  O
# welchen  O  O
# Befundkontext  O  O
# es  O  O
# einzuordnen  O  O
# ist  O  O
# .  O  O
#
# Für  O  O
# diese  O  O
# Arbeit  O  O
# wurden  O  O
# nur  O  O
# die  O  O
# 67  O  O
# zuordenbaren  O  O
# Individuen  O  O
# berücksichtigt  O  O
# .  O  O
#
# 44  O  O
# Zur  O  O
# Nummerierung  O  O
# bzw.  O  O
# Bezeichnung  O  O
# der  O  O
# einzelnen  O  O
# Bestattungen  B-CON  B-CON
# in  O  O
# der  O  O
# vorliegenden  O  O
# Arbeit  O  O
# siehe  O  O
# Erläuterungen  O  O
# im  O  O
# Kapitel  O  O
# 4.2.1  O  O
# .  O  O
#
# Weingarten  B-LOC  O
# Horb-Altheim  B-LOC  O
# Bad  B-LOC  O
# Mingolsheim  I-LOC  O
# Abb  O  O
# .  O  O
#
# 3.1  O  O
# :  O  O
# Lage  O  O
# der  O  O
# Fundorte  O  O
# Bad  B-LOC  O
# Mingolsheim  I-LOC  O
# ,  O  O
# Horb-  B-LOC  O
# Altheim  I-LOC  O
# und  O  O
# Weingarten  B-LOC  O
# .  O  O
#
# untersuchte  O  O
# gräberfelder  B-CON  O
# im  O  O
# überblick  O  O
# 61  O  O
# wurden  O  O
# in  O  O
# der  O  O
# Originaldokumentation  O  O
# als  O  O
# Leichenbrand  B-ART  B-ART
# angesprochen  O  O
# .  O  O
#
# M.  O  O
# Schäfer  O  O
# weist  O  O
# jedoch  O  O
# darauf  O  O
# hin  O  O
# ,  O  O
# dass  O  O
# nicht  O  O
# gesichert  O  O
# von  O  O
# einer  O  O
# Brandbestattung  B-CON  B-CON
# ausgegangen  O  O
# werden  O  O
# kann  O  O
# (  O  O
# Schäfer  O  O
# 2005  B-PER  O
# :  O  O
# 460  O  O
# )  O  O
# .  O  O
#
# Soweit  O  O
# nachvollziehbar  O  O
# waren  O  O
# die  O  O
# Toten  B-ART  O
# in  O  O
# gestreckter  O  B-CON
# Rückenlage  O  I-CON
# mit  O  O
# zumeist  O  O
# parallel  O  O
# am  O  O
# Körper  O  O
# oder  O  O
# auf  O  O
# den  O  O
# Oberschenkeln  O  O
# liegenden  O  O
# Armen  O  O
# beigesetzt  O  O
# worden  O  O
# (  O  O
# Schäfer  O  O
# 2005  B-PER  O
# :  O  O
# 328  O  O
# )  O  O
# .  O  O
#
# Hinweise  O  O
# auf  O  O
# Grabeinbauten  B-CON  O
# konnten  O  O
# in  O  O
# 28  O  O
# Bestattungen  B-CON  B-CON
# dokumentiert  O  O
# werden  O  O
# ,  O  O
# wobei  O  O
# es  O  O
# sich  O  O
# vorwiegend  O  O
# um  O  O
# Reste  O  O
# kammerartiger  B-CON  O
# Holzkonstruktionen  I-CON  O
# handelte  O  O
# ,  O  O
# in  O  O
# denen  O  O
# z.T  O  O
# .  O  O
#
# Spuren  O  O
# von  O  O
# Holzsärgen  B-ART  O
# nachgewiesen  O  O
# wurden  O  O
# (  O  O
# Schäfer  O  O
# 2005  B-PER  O
# :  O  O
# 336–338  O  O
# )  O  O
# .  O  O
#
# Hervorzuheben  O  O
# ist  O  O
# die  O  O
# Bestattung  B-CON  B-CON
# des  O  O
# Mannes  O  O
# aus  O  O
# BM052  O  O
# ,  O  O
# dessen  O  O
# Grab  B-CON  B-CON
# neben  O  O
# Holzkammer  B-CON  O
# und  O  O
# Sarg  B-ART  O
# auch  O  O
# von  O  O
# einem  O  O
# Kreisgraben  B-CON  O
# umgeben  O  O
# war  O  O
# (  O  O
# vgl.  O  O
# Abb  O  O
# .  O  O
#
# 3.2  O  O
# )  O  O
# Generell  O  O
# muss  O  O
# in  O  O
# Bad  B-LOC  B-LOC
# Mingolsheim  I-LOC  I-LOC
# auf  O  O
# die  O  O
# relativ  O  O
# hohe  O  O
# Quote  O  O
# an  O  O
# gestörten  O  O
# Bestattungen  B-CON  B-CON
# hingewiesen  O  O
# werden  O  O
# .  O  O
#
# Nur  O  O
# elf  O  O
# Gräber  B-CON  B-CON
# können  O  O
# als  O  O
# ungestört  O  O
# angesprochen  O  O
# werden  O  O
# .  O  O
#
# Der  O  O
# tatsächliche  O  O
# Anteil  O  O
# an  O  O
# intentional  O  O
# antik  O  O
# manipulierten  O  O
# Gräbern  B-CON  B-CON
# ist  O  O
# jedoch  O  O
# schwierig  O  O
# zu  O  O
# eruieren  O  O
# .  O  O
#
# Schäfer  O  O
# (  O  O
# 2005  B-PER  B-PER
# :  O  O
# 330  O  O
# )  O  O
# spricht  O  O
# von  O  O
# 50  O  O
# betroffenen  O  O
# Bestattungen  B-CON  B-CON
# .  O  O
#
# Tatsächlich  O  O
# lassen  O  O
# sich  O  O
# für  O  O
# viele  O  O
# dieser  O  O
# Fälle  O  O
# aber  O  O
# antike  O  O
# Manipulationen  O  O
# nicht  O  O
# sicher  O  O
# nachweisen  O  O
# ,  O  O
# v.a  O  O
# .  O  O
#
# da  O  O
# durch  O  O
# Beschädigungen  O  O
# bei  O  O
# den  O  O
# modernen  O  O
# Bauarbeiten  O  O
# nicht  O  O
# immer  O  O
# zwischen  O  O
# zeitgenössischer  O  O
# und  O  O
# späterer  O  O
# Störung  O  O
# zu  O  O
# trennen  O  O
# ist  O  O
# .  O  O
#
# Nach  O  O
# kritischer  O  O
# Durchsicht  O  O
# der  O  O
# Grabzeichnungen  O  O
# lässt  O  O
# in  O  O
# etwa  O  O
# die  O  O
# Hälfte  O  O
# der  O  O
# Bestattungen  B-CON  B-CON
# auf  O  O
# antike  O  O
# Grabmanipulation  O  O
# schließen  O  O
# .  O  O
#
# In  O  O
# der  O  O
# räumlichen  O  O
# Struktur  O  O
# des  O  O
# Gräberfeldes  B-CON  O
# folgten  O  O
# die  O  O
# Bestattungen  B-CON  B-CON
# grundsätzlich  O  O
# einer  O  O
# W-O  O  O
# orientierten  O  O
# Ausrichtung  O  O
# ,  O  O
# wobei  O  O
# manchmal  O  O
# stärkere  O  O
# ,  O  O
# manchmal  O  O
# schwächere  O  O
# Schwankungen  O  O
# sowohl  O  O
# in  O  O
# Richtung  O  O
# Norden  O  O
# als  O  O
# auch  O  O
# Süden  O  O
# dokumentiert  O  O
# wurden  O  O
# .  O  O
#
# Eine  O  O
# gänzlich  O  O
# andersartige  O  O
# Orientierung  O  O
# wies  O  O
# nur  O  O
# die  O  O
# Bestattung  B-CON  B-CON
# BM050  O  O
# auf  O  O
# ,  O  O
# welche  O  O
# N-S  O  O
# ausgerichtet  O  O
# war  O  O
# (  O  O
# Abb  O  O
# .  O  O
#
# 3.2  O  O
# )  O  O
# .  O  O
#
# Reihenbildungen  O  O
# sind  O  O
# am  O  O
# Gräberfeldplan  O  O
# generell  O  O
# nur  O  O
# vage  O  O
# zu  O  O
# erkennen  O  O
# ,  O  O
# wohingegen  O  O
# bereits  O  O
# M.  O  O
# N  O  O
# 1  O  O
# 5  O  O
# 10m  O  O
# 20  O  O
# 15  O  O
# 10  O  O
# 16  O  O
# 14  O  O
# 49  O  O
# 21/21a  O  O
# 22  O  O
# 17  O  O
# 19  O  O
# 18  O  O
# 5  O  O
# 8  O  O
# 13  O  O
# 4  O  O
# 7  O  O
# 37  O  O
# 38  O  O
# 39a/b  O  O
# 43  O  O
# 45  O  O
# 40  O  O
# 32  O  O
# 33  O  O
# 12  O  O
# 11  O  O
# 23  O  O
# 34  O  O
# 41  O  O
# 42  O  O
# 35  O  O
# 28  O  O
# 26  O  O
# 25  O  O
# 24  O  O
# 47  O  O
# 48-1/-2  O  O
# 46  O  O
# 51  O  O
# 52  O  O
# 55  O  O
# 63  O  O
# 64  O  O
# 50  O  O
# 62  O  O
# 53  O  O
# 54  O  O
# 58  O  O
# 60  O  O
# 59  O  O
# 57  O  O
# 31  O  O
# 30  O  O
# 29  O  O
# 44a-c  O  O
# 6a/b  O  O
# 61  O  O
# 3  O  O
# 1  O  O
# 2  O  O
# Abb  O  O
# .  O  O
#
# 3.2  O  O
# :  O  O
# Bad  B-LOC  O
# Mingolsheim  I-LOC  O
# .  O  O
#
# Gräberfeldplan  O  O
# .  O  O
#
# 62  O  O
# am  O  O
# rande  O  O
# des  O  O
# grabs  B-CON  O
# Schäfer  O  O
# auf  O  O
# die  O  O
# mitunter  O  O
# deutlich  O  O
# erkennbaren  O  O
# Leerflächen  O  O
# zwischen  O  O
# einzelnen  O  O
# Bestattungen  B-CON  O
# hingewiesen  O  O
# hat  O  O
# sowie  O  O
# auf  O  O
# einen  O  O
# möglichen  O  O
# Pfad  B-CON  O
# ,  O  O
# welcher  O  O
# die  O  O
# Freifläche  O  O
# erklären  O  O
# könnte  O  O
# die  O  O
# das  O  O
# Gräberfeld  B-CON  B-CON
# von  O  O
# Nord  O  O
# nach  O  O
# Süd  O  O
# deutlich  O  O
# trennt  O  O
# (  O  O
# Schäfer  O  O
# 2005  B-PER  O
# :  O  O
# 327  O  O
# )  O  O
# .  O  O
#
# Die  O  O
# Grenzen  O  O
# des  O  O
# Gräberfeldes  B-CON  O
# wurden  O  O
# nur  O  O
# im  O  O
# Westen  O  O
# mit  O  O
# Sicherheit  O  O
# erfasst  O  O
# ,  O  O
# während  O  O
# die  O  O
# Ausdehnung  O  O
# nach  O  O
# Norden  O  O
# und  O  O
# Süden  O  O
# teilweise  O  O
# ungeklärt  O  O
# ist  O  O
# .  O  O
#
# Mit  O  O
# Sicherheit  O  O
# nicht  O  O
# vollständig  O  O
# erschlossen  O  O
# wurde  O  O
# der  O  O
# östliche  O  O
# Bereich  O  O
# des  O  O
# Bestattungsareals  B-CON  O
# ,  O  O
# welcher  O  O
# durch  O  O
# bereits  O  O
# ältere  O  O
# Bautätigkeiten  O  O
# zerstört  O  O
# war  O  O
# .  O  O
#
# Die  O  O
# Größe  O  O
# der  O  O
# frühmittelalterlichen  B-PER  O
# Bestattungsgemeinschaft  O  O
# ist  O  O
# also  O  O
# nicht  O  O
# gänzlich  O  O
# rekonstruierbar  O  O
# ,  O  O
# wird  O  O
# aber  O  O
# von  O  O
# M.  O  O
# Schäfer  O  O
# auf  O  O
# über  O  O
# 100  O  O
# Personen  O  O
# geschätzt  O  O
# (  O  O
# Schäfer  O  O
# 2005  B-PER  O
# :  O  O
# 323  O  O
# )  O  O
# .  O  O
#
# In  O  O
# ca  O  O
# .  O  O
#
# 80.0  O  O
# %  O  O
# der  O  O
# Bestattungen  O  B-CON
# konnten  O  O
# Gegenstände  O  O
# bzw.  O  O
# Grabfunde  O  O
# verzeichnet  O  O
# werden  O  O
# .  O  O
#
# Neun  O  O
# Bestattungen  B-CON  O
# wiesen  O  O
# keine  O  O
# Beigaben  O  O
# auf  O  O
# (  O  O
# Schäfer  O  O
# 2005  B-PER  O
# :  O  O
# 335  O  O
# ,  O  O
# Anm  O  O
# .  O  O
#
# 151  O  O
# )  O  O
# .  O  O
#
# In  O  O
# vier  O  O
# weiteren  O  O
# Gräbern  B-CON  B-CON
# konnte  O  O
# durch  O  O
# die  O  O
# Störungen  O  O
# nicht  O  O
# mehr  O  O
# entschieden  O  O
# werden  O  O
# zu  O  O
# welcher  O  O
# Bestattung  B-CON  B-CON
# die  O  O
# aus  O  O
# den  O  O
# Grabschächten  B-CON  O
# stammenden  O  O
# Objekte  O  O
# ursprünglich  O  O
# gehörten45  O  O
# .  O  O
#
# Auf  O  O
# Basis  O  O
# der  O  O
# typochronologischen  O  O
# Auswertung  O  O
# des  O  O
# 45  O  O
# BM006b  O  O
# ,  O  O
# BM044b-1  O  O
# ,  O  O
# BM044b-2  O  O
# und  O  O
# BM044c  O  O
# .  O  O
#
# Bei  O  O
# der  O  O
# Aufnahme  O  O
# in  O  O
# die  O  O
# Datenbank  O  O
# wurden  O  O
# diese  O  O
# Bestattungen  B-CON  O
# als  O  O
# beigabenlos  O  O
# aufgenommen  O  O
# .  O  O
#
# Abb  O  O
# .  O  O
#
# 3.3  O  O
# :  O  O
# Bad  B-LOC  O
# Mingolsheim  I-LOC  O
# .  O  O
#
# Altersverteilung  O  O
# nach  O  O
# Geschlecht  O  O
# .  O  O
#
# untersuchte  O  O
# gräberfelder  B-CON  O
# im  O  O
# überblick  O  O
# 63  O  O
# Fundmaterials  O  O
# unterteilte  O  O
# M.  O  O
# Schäfer  O  O
# das  O  O
# Gräberfeld  B-CON  B-CON
# in  O  O
# drei  O  O
# Belegungsphasen  O  O
# mit  O  O
# zwei  O  O
# Übergangsphasen  O  O
# .  O  O
#
# Demzufolge  O  O
# beginnt  O  O
# die  O  O
# Belegungszeit  O  O
# des  O  O
# Gräberfelds  O  O
# in  O  O
# Phase  O  O
# 1  O  O
# etwa  O  O
# um  O  O
# 580  B-PER  B-PER
# n.  I-PER  I-PER
# Chr.  I-PER  I-PER
# und  O  O
# endet  O  O
# ca  O  O
# .  O  O
#
# um  O  O
# 680  B-PER  O
# am  O  O
# Übergang  O  O
# der  O  O
# Phase  O  O
# 2  O  O
# zu  O  O
# Phase  O  O
# 3  O  O
# ,  O  O
# welche  O  O
# jedoch  O  O
# von  O  O
# Schäfer  O  O
# nicht  O  O
# weiter  O  O
# ausdifferenziert  O  O
# wurde46  O  O
# .  O  O
#
# In  O  O
# das  O  O
# Chronologiesystem  O  O
# der  O  O
# „  O  O
# Kleiderphasen  O  O
# “  O  O
# (  O  O
# KP  O  O
# )  O  O
# nach  O  O
# C.  O  O
# Döhrer  O  O
# (  O  O
# 2011  B-PER  B-PER
# :  O  O
# 50–  O  O
# 55  O  O
# ;  O  O
# siehe  O  O
# hierzu  O  O
# Unterkapitel  O  O
# 3.3  O  O
# )  O  O
# übersetzt  O  O
# ,  O  O
# datiert  O  O
# Bad  B-LOC  O
# Mingolsheim  I-LOC  O
# demnach  O  O
# vereinzelt  O  O
# ab  O  O
# der  O  O
# Spätphase  O  O
# von  O  O
# KP2  O  O
# ,  O  O
# hat  O  O
# seinen  O  O
# markanten  O  O
# Schwerpunkt  O  O
# in  O  O
# KP3  O  O
# und  O  O
# läuft  O  O
# dann  O  O
# zu  O  O
# Beginn  O  O
# von  O  O
# KP4  O  O
# nach  O  O
# etwa  O  O
# 100-jähriger  O  O
# Belegungsdauer  O  O
# aus  O  O
# .  O  O
#
# In  O  O
# Zusammenschau  O  O
# mit  O  O
# der  O  O
# geschätzten  O  O
# Anzahl  O  O
# von  O  O
# ca  O  O
# .  O  O
#
# 100  O  O
# ursprünglichen  O  O
# Bestattungen  B-CON  B-CON
# ,  O  O
# kann  O  O
# für  O  O
# Mingolsheim  B-LOC  O
# basierend  O  O
# auf  O  O
# den  O  O
# Überlegungen  O  O
# R.  O  O
# Schregs  O  O
# (  O  O
# 2006  B-PER  B-PER
# :  O  O
# 278  O  O
# )  O  O
# zur  O  O
# mittelalterlichen  B-PER  B-PER
# Dorfgenese  O  O
# von  O  O
# einer  O  O
# durchschnittlichen  O  O
# Lebendbevölkerung  O  O
# von  O  O
# 30  O  O
# Personen  O  O
# ausgegangen  O  O
# werden  O  O
# ,  O  O
# was  O  O
# einer  O  O
# Größe  O  O
# von  O  O
# ca  O  O
# .  O  O
#
# drei  O  O
# Gehöften  B-CON  O
# entspricht  O  O
# .  O  O
#
# Die  O  O
# anthropologischen  O  O
# Alters-  O  O
# und  O  O
# Geschlechtsbestimmungen  O  O
# (  O  O
# Czarnetzki  O  O
# 2005  B-PER  B-PER
# )  O  O
# konstatieren  O  O
# eine  O  O
# Zusammensetzung  O  O
# der  O  O
# Bestattungspopulation  O  O
# aus  O  O
# 35  O  O
# weiblichen  O  O
# und  O  O
# 27  O  O
# männlichen  O  O
# Individuen47  O  O
# ,  O  O
# was  O  O
# einen  O  O
# Maskulinitätsindex  O  O
# MI=77.1  O  O
# ergibt48  O  O
# .  O  O
#
# Bei  O  O
# fünf  O  O
# Bestattungen  B-CON  B-CON
# konnte  O  O
# das  O  O
# biologische  O  O
# Geschlecht  O  O
# nicht  O  O
# erhoben  O  O
# werden  O  O
# (  O  O
# Tab  O  O
# .  O  O
#
# B.1  O  O
# )  O  O
# .  O  O
#
# Es  O  O
# ist  O  O
# zu  O  O
# beachten  O  O
# ,  O  O
# dass  O  O
# M.  O  O
# Schäfer  O  O
# (  O  O
# 2005  B-PER  B-PER
# :  O  O
# 325f  O  O
# .  O  O
# )  O  O
#
# in  O  O
# seiner  O  O
# Auswertung  O  O
# eine  O  O
# nach  O  O
# seinem  O  O
# persönlichen  O  O
# Ermessen  O  O
# eruierte  O  O
# Kombination  O  O
# der  O  O
# anthropologischen  O  O
# Daten  O  O
# und  O  O
# der  O  O
# archäologischen  O  O
# Ausstattung  O  O
# zur  O  O
# Geschlechtsbestimmung  O  O
# verwendete  O  O
# .  O  O
#
# Dementsprechend  O  O
# können  O  O
# die  O  O
# in  O  O
# der  O  O
# vorliegenden  O  O
# Arbeit  O  O
# verwendeten  O  O
# Werte  O  O
# nicht  O  O
# direkt  O  O
# mit  O  O
# der  O  O
# Präsentation  O  O
# altersund  O  O
# geschlechtsbezogener  O  O
# Aspekte  O  O
# in  O  O
# Schäfers  O  O
# Arbeit  O  O
# verglichen  O  O
# werden  O  O
# ,  O  O
# da  O  O
# hier  O  O
# nur  O  O
# die  O  O
# anthropologischen  O  O
# Daten  O  O
# nach  O  O
# Czarnetzki  O  O
# (  O  O
# 2005  B-PER  B-PER
# )  O  O
# herangezogen  O  O
# wurden  O  O
# .  O  O
#
# Die  O  O
# allgemeine  O  O
# Altersverteilung  O  O
# zeigt  O  O
# einen  O  O
# Schwerpunkt  O  O
# bei  O  O
# den  O  O
# (  O  O
# spät  O  O
# )  O  O
# adult  O  O
# verstorbenen  O  O
# Personen  O  O
# .  O  O
#
# Ca  O  O
# .  O  O
#
# 28.0  O  O
# %  O  O
# entfallen  O  O
# auf  O  O
# subadulte  O  O
# Individuen  O  O
# bzw.  O  O
# 22.0  O  O
# %  O  O
# auf  O  O
# Kinder  O  O
# bis  O  O
# zum  O  O
# 14  O  O
# .  O  O
#
# Lebensjahr  O  O
# .  O  O
#
# In  O  O
# der  O  O
# geschlechtsspezifischen  O  O
# Altersverteilung  O  O
# ist  O  O
# der  O  O
# erhöhte  O  O
# Anteil  O  O
# an  O  O
# weiblichen  O  O
# Individuen  O  O
# bei  O  O
# den  O  O
# Kindern  O  O
# und  O  O
# frühadult  O  O
# Verstorbenen  O  O
# hervorzuheben  O  O
# sowie  O  O
# die  O  O
# Überzahl  O  O
# an  O  O
# Männern  O  O
# in  O  O
# der  O  O
# Gruppe  O  O
# der  O  O
# Spätadulten  O  O
# (  O  O
# Abb  O  O
# .  O  O
#
# 3.3  O  O
# )  O  O
# .  O  O
#
# Neben  O  O
# der  O  O
# detaillierten  O  O
# Materialvorlage  O  O
# durch  O  O
# M.  O  O
# Schäfer  O  O
# ,  O  O
# sowie  O  O
# dessen  O  O
# Versuch  O  O
# die  O  O
# Mingolsheimer  B-LOC  O
# Grabinventare  B-CON  O
# in  O  O
# die  O  O
# Qualitätsgruppen  O  O
# nach  O  O
# R.  O  O
# Christlein  O  O
# (  O  O
# 1966  O  B-PER
# ;  O  O
# 1973  O  B-PER
# )  O  O
# zu  O  O
# untergliedern49  O  O
# ,  O  O
# liegt  O  O
# für  O  O
# die  O  O
# menschlichen  B-SPE  B-SPE
# Skelettreste  B-ART  O
# des  O  O
# Gräberfeldes  B-CON  O
# auch  O  O
# die  O  O
# bereits  O  O
# erwähnte  O  O
# anthropologische  O  O
# Bearbeitung  O  O
# durch  O  O
# A.  O  O
# Czarnetzki  O  O
# (  O  O
# 2005  O  B-PER
# )  O  O
# vor  O  O
# .  O  O
#
# Czarnetzki  O  O
# untersuchte  O  O
# die  O  O
# Skelette  B-ART  B-ART
# zusätzlich  O  O
# zur  O  O
# Alters-  O  O
# und  O  O
# Geschlechtsbestimmung  O  O
# auch  O  O
# auf  O  O
# Spuren  O  O
# pathologischer  O  O
# Veränderungen  O  O
# hin  O  O
# und  O  O
# präsentierte  O  O
# seine  O  O
# Ergebnisse  O  O
# in  O  O
# ...
# x  O  O
# 40  O  O
# x  O  O
# 41  O  O
# x  O  O
# 42  O  O
# x  O  O
# Abb  O  O
# .  O  O
#
# 3  O  O
# Dortmund-Asseln  B-LOC  O
# ,  O  O
# Übersicht  O  O
# über  O  O
# die  O  O
# Grabformen  O  O
# .  O  O
#
# 218  O  O
# Patrick  O  O
# Könemann  O  O
# Ausgrabungen  O  O
# und  O  O
# Funde  O  O
# in  O  O
# Westfalen-Lippe  B-LOC  B-LOC
# 12  O  O
# Grab  B-CON  B-CON
# Leichenbrandgewicht  O  O
# Knochenauswahl  O  O
# Geschlecht  O  O
# anthropologisch  O  O
# 1  O  O
# 212  O  O
# g  O  O
# Schädel  O  B-ART
# ,  O  O
# Rumpf  O  O
# ,  O  O
# Extremitäten  O  O
# Tendenz  O  O
# Mann  O  O
# 2  O  O
# 169  O  O
# g  O  O
# Schädel  O  B-ART
# ,  O  O
# Rumpf  O  O
# ,  O  O
# Extremitäten  O  O
# nicht  O  O
# bestimmbar  O  O
# 3  O  O
# 816  O  O
# g  O  O
# Schädel  O  B-ART
# ,  O  O
# Rumpf  O  O
# ,  O  O
# Extremitäten  O  O
# Tendenz  O  O
# Mann  O  O
# 4  O  O
# 121  O  O
# g  O  O
# Schädel  O  B-ART
# ,  O  O
# Rumpf  O  O
# ,  O  O
# Extremitäten  O  O
# schwache  O  O
# Tendenz  O  O
# Mann  O  O
# 5  O  O
# 293  O  O
# g  O  O
# Schädel  O  B-ART
# ,  O  O
# Rumpf  O  O
# ,  O  O
# Extremitäten  O  O
# Tendenz  O  O
# Mann  O  O
# 6  O  O
# 260  O  O
# g  O  O
# Schädel  O  B-ART
# ,  O  O
# Rumpf  O  O
# ,  O  O
# Extremitäten  O  O
# Tendenz  O  O
# Mann  O  O
# 7  O  O
# 363  O  O
# g  O  O
# Schädel  O  B-ART
# ,  O  O
# Extremitäten  O  O
# Tendenz  O  O
# Mann  O  O
# 8  O  O
# 161  O  O
# g  O  O
# Schädel  O  B-ART
# ,  O  O
# Rumpf  O  O
# ,  O  O
# Extremitäten  O  O
# schwache  O  O
# Tendenz  O  O
# Mann  O  O
# 9  O  O
# 221  O  O
# g  O  O
# Schädel  O  B-ART
# ,  O  O
# Rumpf  O  O
# ,  O  O
# Extremitäten  O  O
# Tendenz  O  O
# Mann  O  O
# 10  O  O
# 637  O  O
# g  O  O
# Schädel  O  B-ART
# ,  O  O
# Rumpf  O  O
# ,  O  O
# Extremitäten  O  O
# Tendenz  O  O
# Mann  O  O
# 11  O  O
# 56  O  O
# g  O  O
# Schädel  O  B-ART
# ,  O  O
# Rumpf  O  O
# ,  O  O
# Extremitäten  O  O
# Tendenz  O  O
# Frau  O  O
# 12  O  O
# 312  O  O
# g  O  O
# Schädel  O  B-ART
# ,  O  O
# Rumpf  O  O
# ,  O  O
# Extremitäten  O  O
# Tendenz  O  O
# Frau  O  O
# 13  O  O
# 137  O  O
# g  O  O
# Schädel  O  B-ART
# ,  O  O
# Rumpf  O  O
# ,  O  O
# Extremitäten  O  O
# schwache  O  O
# Tendenz  O  O
# Mann  O  O
# 14  O  O
# 76  O  O
# g  O  O
# Schädel  O  B-ART
# ,  O  O
# Extremitäten  O  O
# schwache  O  O
# Tendenz  O  O
# Frau  O  O
# 15  O  O
# 2  O  O
# g  O  O
# Schädel  O  B-ART
# ,  O  O
# Extremitäten  O  O
# nicht  O  O
# bestimmbar  O  O
# 16  O  O
# 10  O  O
# g  O  O
# Schädel  O  B-ART
# ,  O  O
# Extremitäten  O  O
# schwache  O  O
# Tendenz  O  O
# Frau  O  O
# 17  O  O
# 69  O  O
# g  O  O
# Schädel  O  B-ART
# ,  O  O
# Extremitäten  O  O
# Tendenz  O  O
# Mann  O  O
# 18  O  O
# 11  O  O
# g  O  O
# Schädel  O  B-ART
# ,  O  O
# Rumpf  O  O
# ,  O  O
# Extremitäten  O  O
# nicht  O  O
# bestimmbar  O  O
# 19  O  O
# 1  O  O
# g  O  O
# Schädel  O  B-ART
# ,  O  O
# Extremitäten  O  O
# nicht  O  O
# bestimmbar  O  O
# 20  O  O
# 200  O  O
# g  O  O
# Schädel  O  B-ART
# ,  O  O
# Extremitäten  O  O
# schwache  O  O
# Tendenz  O  O
# Frau  O  O
# 21  O  O
# 17  O  O
# g  O  O
# Schädel  O  B-ART
# ,  O  O
# Extremitäten  O  O
# nicht  O  O
# bestimmbar  O  O
# 22  O  O
# nicht  O  O
# bestimmt  O  O
# 23  O  O
# 134  O  O
# g  O  O
# Schädel  O  B-ART
# ,  O  O
# Rumpf  O  O
# ,  O  O
# Extremitäten  O  O
# nicht  O  O
# bestimmbar  O  O
# 24  O  O
# 195  O  O
# g  O  O
# Schädel  O  B-ART
# ,  O  O
# Extremitäten  O  O
# Tendenz  O  O
# Frau  O  O
# 25  O  O
# nicht  O  O
# erhalten  O  O
# nicht  O  O
# erhalten  O  O
# nicht  O  O
# bestimmbar  O  O
# 26  O  O
# 50  O  O
# g  O  O
# Schädel  O  B-ART
# ,  O  O
# Extremitäten  O  O
# schwache  O  O
# Tendenz  O  O
# Frau  O  O
# 27  O  O
# 2  O  O
# g  O  O
# Schädel  O  B-ART
# ,  O  O
# Extremitäten  O  O
# nicht  O  O
# bestimmbar  O  O
# 28  O  O
# 44  O  O
# g  O  O
# Schädel  O  B-ART
# ,  O  O
# Rumpf  O  O
# ,  O  O
# Extremitäten  O  O
# nicht  O  O
# bestimmbar  O  O
# 29  O  O
# 168  O  O
# g  O  O
# Schädel  O  B-ART
# ,  O  O
# Rumpf  O  O
# ,  O  O
# Extremitäten  O  O
# Tendenz  O  O
# Mann  O  O
# 30  O  O
# 10  O  O
# g  O  O
# Schädel  O  B-ART
# ,  O  O
# Rumpf  O  O
# ,  O  O
# Extremitäten  O  O
# schwache  O  O
# Tendenz  O  O
# Frau  O  O
# 31  O  O
# 471  O  O
# g  O  O
# Schädel  O  B-ART
# ,  O  O
# Rumpf  O  O
# ,  O  O
# Extremitäten  O  O
# Tendenz  O  O
# Frau  O  O
# 32  O  O
# 123  O  O
# g  O  O
# Extremitäten  O  O
# Tendenz  O  O
# Frau  O  O
# 33  O  O
# 240  O  O
# g  O  O
# Schädel  O  B-ART
# ,  O  O
# Rumpf  O  O
# ,  O  O
# Extremitäten  O  O
# schwache  O  O
# Tendenz  O  O
# Mann  O  O
# 34  O  O
# 295  O  O
# g  O  O
# Schädel  O  B-ART
# ,  O  O
# Extremitäten  O  O
# Tendenz  O  O
# Mann  O  O
# 35  O  O
# 272  O  O
# g  O  O
# Schädel  O  B-ART
# ,  O  O
# Extremitäten  O  O
# schwache  O  O
# Tendenz  O  O
# Frau  O  O
# 36  O  O
# 241  O  O
# g  O  O
# Schädel  O  B-ART
# ,  O  O
# Extremitäten  O  O
# schwache  O  O
# Tendenz  O  O
# Mann  O  O
# 37  O  O
# 693  O  O
# g  O  O
# Schädel  O  B-ART
# ,  O  O
# Extremitäten  O  O
# nicht  O  O
# bestimmbar  O  O
# 38  O  O
# 314  O  O
# g  O  O
# Schädel  O  B-ART
# ,  O  O
# Rumpf  O  O
# ,  O  O
# Extremitäten  O  O
# schwache  O  O
# Tendenz  O  O
# Mann  O  O
# 39  O  O
# 192  O  O
# g  O  O
# Schädel  O  B-ART
# ,  O  O
# Extremitäten  O  O
# schwache  O  O
# Tendenz  O  O
# Mann  O  O
# 40  O  O
# 791  O  O
# g  O  O
# Schädel  O  B-ART
# ,  O  O
# Rumpf  O  O
# ,  O  O
# Extremitäten  O  O
# nicht  O  O
# bestimmbar  O  O
# 41  O  O
# 855  O  O
# g  O  O
# Schädel  O  B-ART
# ,  O  O
# Rumpf  O  O
# ,  O  O
# Extremitäten  O  O
# Tendenz  O  O
# Frau  O  O
# 42  O  O
# nicht  O  O
# bestimmt  O  O
# Abb  O  O
# .  O  O
#
# 4  O  O
# Dortmund-Asseln  B-LOC  O
# ,  O  O
# anthropologische  O  O
# Angaben  O  O
# zu  O  O
# den  O  O
# Leichenbränden  B-CON  O
# .  O  O
#
# Das  O  O
# Gräberfeld  B-CON  O
# der  O  O
# römischen  B-PER  B-PER
# Kaiserzeit  I-PER  I-PER
# und  O  O
# frühen  B-PER  O
# Völkerwanderungszeit  I-PER  O
# von  O  O
# Dortmund-Asseln  B-LOC  O
# 219  O  O
# Ausgrabungen  O  O
# und  O  O
# Funde  O  O
# in  O  O
# Westfalen-Lippe  B-LOC  B-LOC
# 12  O  O
# Geschlecht  O  O
# archäologisch  O  O
# Alter  O  O
# Tierknochen  B-ART  B-ART
# erwachsen  O  O
# unklar  O  O
# (  O  O
# Fibel/Kerbschnittgürtelgarnitur  B-ART  O
# )  O  O
# erwachsen  O  O
# 30–50  O  O
# Jahre  O  O
# erwachsen  O  O
# Tendenz  O  O
# Frau  O  O
# (  O  O
# Fibel  B-ART  O
# )  O  O
# über  O  O
# 50  O  O
# Jahre  O  O
# über  O  O
# 50  O  O
# Jahre  O  O
# 22  O  O
# g  O  O
# ,  O  O
# Art  O  O
# nicht  O  O
# bestimmbar  O  O
# 40–60  O  O
# Jahre  O  O
# 20  O  O
# g  O  O
# ,  O  O
# Langknochen  B-ART  B-ART
# vom  O  O
# Schwein  B-SPE  B-SPE
# Tendenz  O  O
# Frau  O  O
# (  O  O
# Fibel  B-ART  O
# )  O  O
# über  O  O
# 50  O  O
# Jahre  O  O
# Tendenz  O  O
# Mann  O  O
# (  O  O
# Kerbschnittgürtelgarnitur  B-ART  O
# )  O  O
# erwachsen  O  O
# Tendenz  O  O
# Frau  O  O
# (  O  O
# Haarpfeil  B-ART  O
# )  O  O
# 40–60  O  O
# Jahre  O  O
# erwachsen  O  O
# 30  O  O
# g  O  O
# ,  O  O
# Langknochen  B-ART  B-ART
# vom  O  O
# Schwein  B-SPE  B-SPE
# ,  O  O
# Jungtier  O  O
# erwachsen  O  O
# 20–30  O  O
# Jahre  O  O
# erwachsen  O  O
# 0–1  O  O
# Jahr  O  O
# erwachsen  O  O
# erwachsen  O  O
# 2  O  O
# g  O  O
# ,  O  O
# Art  O  O
# nicht  O  O
# bestimmbar  O  O
# erwachsen  O  O
# 0–2  O  O
# Jahre  O  O
# 20–30  O  O
# Jahre  O  O
# erwachsen  O  O
# ?  O  O
#
# 8–12  O  O
# Jahre  O  O
# Tendenz  O  O
# Frau  O  O
# (  O  O
# Haarpfeil  B-ART  O
# ,  O  O
# Fibeln  B-ART  B-ART
# )  O  O
# erwachsen  O  O
# Tendenz  O  O
# Frau  O  O
# (  O  O
# Fibel  B-ART  O
# )  O  O
# erwachsen  O  O
# erwachsen  O  O
# eher  O  O
# erwachsen  O  O
# 1–3  O  O
# Jahre  O  O
# 6  O  O
# g  O  O
# ,  O  O
# vom  O  O
# Schwein  B-SPE  B-SPE
# ,  O  O
# Jungtier  O  O
# 30–50  O  O
# Jahre  O  O
# eher  O  O
# erwachsen  O  O
# 50–70  O  O
# Jahre  O  O
# erwachsen  O  O
# über  O  O
# 60  O  O
# Jahre  O  O
# über  O  O
# 60  O  O
# Jahre  O  O
# erwachsen  O  O
# erwachsen  O  O
# 20–40  O  O
# Jahre  O  O
# 30–50  O  O
# Jahre  O  O
# 14–18  O  O
# Jahre  O  O
# 20–40  O  O
# Jahre  O  O
# 20–30  O  O
# Jahre  O  O
# 30  O  O
# g  O  O
# ,  O  O
# Langknochen  B-ART  B-ART
# ,  O  O
# Becken  O  O
# ,  O  O
# Schulterblatt  O  O
# ,  O  O
# Art  O  O
# nicht  O  O
# bestimmbar  O  O
# 220  O  O
# Patrick  O  O
# Könemann  O  O
# Ausgrabungen  O  O
# und  O  O
# Funde  O  O
# in  O  O
# Westfalen-Lippe  B-LOC  B-LOC
# 12  O  O
# chen  O  O
# Gräbern  B-CON  B-CON
# ausgeglichen  O  O
# .  O  O
#
# Sieben  O  O
# der  O  O
# Bestatteten  O  O
# verstarben  O  O
# in  O  O
# einem  O  O
# Alter  O  O
# von  O  O
# 30  O  B-PER
# bis  O  I-PER
# 50  O  I-PER
# Jahren  O  I-PER
# .  O  O
#
# In  O  O
# Grab  B-CON  B-CON
# 39  O  O
# wurde  O  O
# offenbar  O  O
# ein  O  O
# junger  O  O
# Mann  O  O
# beerdigt  O  O
# ,  O  O
# der  O  O
# in  O  O
# einem  O  O
# Alter  O  O
# von  O  O
# 14  O  O
# bis  O  O
# 18  O  O
# Jahren  O  O
# verstarb  O  O
# .  O  O
#
# Über  O  O
# 50  O  O
# Jahre  O  O
# alt  O  O
# waren  O  O
# die  O  O
# Personen  O  O
# aus  O  O
# den  O  O
# Gräbern  B-CON  B-CON
# 31  O  O
# und  O  O
# 34  O  O
# .  O  O
#
# Abgesehen  O  O
# von  O  O
# Kindern  O  O
# sind  O  O
# in  O  O
# dem  O  O
# östlichen  O  O
# Bereich  O  O
# alle  O  O
# Altersstadien  O  O
# vertreten  O  O
# .  O  O
#
# Im  O  O
# westlichen  O  O
# Areal  O  O
# sind  O  O
# nach  O  O
# anthropologischen  O  O
# Gesichtspunkten  O  O
# und  O  O
# dem  O  O
# derzeitigen  O  O
# Ausgrabungsstand  O  O
# bei  O  O
# den  O  O
# kaiserzeitlichen  B-PER  B-PER
# Gräbern  B-CON  B-CON
# Männer  O  O
# klar  O  O
# überrepräsentiert  O  O
# .  O  O
#
# Diese  O  O
# sind  O  O
# zumindest  O  O
# tendenziell  O  O
# nach  O  O
# anthropologischen  O  O
# Untersuchungen  O  O
# in  O  O
# zehn  O  O
# Fällen  O  O
# nachgewiesen  O  O
# ,  O  O
# nur  O  O
# fünf  O  O
# Individuen  O  O
# können  O  O
# als  O  O
# Frauen  O  O
# angesprochen  O  O
# werden  O  O
# .  O  O
#
# In  O  O
# mehreren  O  O
# Männergräbern  B-CON  O
# befinden  O  O
# sich  O  O
# jedoch  O  O
# Objekte  O  O
# ,  O  O
# die  O  O
# in  O  O
# der  O  O
# archäologischen  O  O
# Forschung  O  O
# eher  O  O
# mit  O  O
# Frauen  O  O
# assoziiert  O  O
# werden  O  O
# .  O  O
#
# Es  O  O
# handelt  O  O
# sich  O  O
# hierbei  O  O
# um  O  O
# einen  O  O
# Haarpfeil  B-ART  O
# aus  O  O
# Grab  B-CON  B-CON
# 10  O  O
# und  O  O
# um  O  O
# Fibeln  B-ART  B-ART
# mit  O  O
# kastenförmigem  O  O
# Nadelhalter  O  O
# der  O  O
# Gruppe  O  O
# Almgren  B-ART  O
# VI  I-ART  O
# ,  O  O
# 2  O  O
# in  O  O
# den  O  O
# Gräbern  B-CON  B-CON
# 2  O  O
# ,  O  O
# 5  O  O
# ,  O  O
# 8  O  O
# und  O  O
# 24  O  O
# .  O  O
#
# 92  O  O
# Möglicherweise  O  O
# wurden  O  O
# in  O  O
# diesen  O  O
# Gräbern  B-CON  B-CON
# doch  O  O
# Frauen  O  O
# statt  O  O
# Männer  O  O
# bestattet  O  O
# .  O  O
#
# Durch  O  O
# die  O  O
# geringen  O  O
# Mengen  O  O
# an  O  O
# Leichenbrand  B-CON  B-CON
# ,  O  O
# die  O  O
# in  O  O
# die  O  O
# Gräber  B-CON  B-CON
# gelangten  O  O
# und  O  O
# nur  O  O
# tendenzielle  O  O
# Aussagen  O  O
# über  O  O
# das  O  O
# Geschlecht  O  O
# zuließen  O  O
# ,  O  O
# ist  O  O
# eine  O  O
# endgültige  O  O
# Bewertung  O  O
# nicht  O  O
# möglich  O  O
# .  O  O
#
# Das  O  O
# Grab  B-CON  B-CON
# 2  O  O
# beinhaltete  O  O
# neben  O  O
# einer  O  O
# dieser  O  O
# Fibeln  B-ART  B-ART
# auch  O  O
# eine  O  O
# Astragalröhre  B-ART  O
# einer  O  O
# Kerbschnittgürtelgarnitur  B-ART  O
# .  O  O
#
# Die  O  O
# Gürtelgarnituren  B-ART  O
# gelten  O  O
# eher  O  O
# als  O  O
# Männerattribut  O  O
# ,  O  O
# kommen  O  O
# aber  O  O
# vereinzelt  O  O
# auch  O  O
# in  O  O
# Frauengräbern  B-CON  O
# vor  O  O
# .  O  O
#
# 93  O  O
# Nur  O  O
# bei  O  O
# den  O  O
# Gräbern  B-CON  B-CON
# 9  O  O
# und  O  O
# 24  O  O
# decken  O  O
# sich  O  O
# ,  O  O
# durch  O  O
# die  O  O
# Kerbschnittgürtelgarnitur  B-ART  O
# bzw.  O  O
# die  O  O
# Fibel  B-ART  O
# mit  O  O
# kastenförmigem  O  O
# Nadelhalter  B-ART  O
# ,  O  O
# die  O  O
# archäologischen  O  O
# und  O  O
# anthropologischen  O  O
# Analysen  O  O
# des  O  O
# Geschlechts  O  O
# .  O  O
#
# In  O  O
# je  O  O
# einem  O  O
# Fall  O  O
# handelt  O  O
# es  O  O
# sich  O  O
# bei  O  O
# den  O  O
# spätkaiserzeitlichen  B-PER  O
# Toten  O  O
# um  O  O
# einen  O  O
# Säugling  O  O
# (  O  O
# Grab  B-CON  B-CON
# 28  O  I-CON
# )  O  O
# und  O  O
# ein  O  O
# Kind  O  O
# zwischen  O  B-PER
# 8  O  I-PER
# und  O  I-PER
# 12  O  I-PER
# Jahren  O  I-PER
# (  O  O
# Grab  B-CON  B-CON
# 23  O  O
# )  O  O
# .  O  O
#
# Zwei  O  O
# weitere  O  O
# Säuglingsgräber  B-CON  B-CON
# (  O  O
# Grab  B-CON  B-CON
# 15  O  O
# und  O  O
# 19  O  O
# )  O  O
# beinhalteten  O  O
# keine  O  O
# Beigaben  O  O
# .  O  O
#
# Elf  O  O
# Personen  O  O
# starben  O  O
# in  O  O
# einem  O  O
# adulten  O  O
# Lebensstadium  O  O
# zwischen  O  B-PER
# 20  O  I-PER
# und  O  I-PER
# 50  O  I-PER
# Jahren  O  I-PER
# (  O  O
# Grab  B-CON  B-CON
# 2  O  O
# ,  O  O
# 3  O  O
# ,  O  O
# 4  O  O
# ,  O  O
# 9  O  O
# ,  O  O
# 12  O  O
# ,  O  O
# 13  O  O
# ,  O  O
# 18  O  O
# ,  O  O
# 20  O  O
# ,  O  O
# 24  O  O
# ,  O  O
# 29  O  O
# )  O  O
# .  O  O
#
# Älter  O  O
# wurden  O  O
# nachweislich  O  O
# drei  O  O
# Individuen  O  O
# (  O  O
# Grab  B-CON  O
# 5  O  O
# ,  O  O
# 6  O  O
# und  O  O
# 8  O  O
# )  O  O
# ,  O  O
# während  O  O
# zwei  O  O
# weitere  O  O
# Personen  O  O
# (  O  O
# Grab  B-CON  B-CON
# 92  O  O
# Zu  O  O
# den  O  O
# Haarpfeilen  B-ART  O
# Böhme  O  O
# 1974  B-PER  B-PER
# ,  O  O
# 35–39  O  O
# ;  O  O
# Werner  O  O
# 1990  B-PER  B-PER
# .  O  O
#
# Zu  O  O
# den  O  O
# Fibeln  B-ART  B-ART
# Böhme  O  O
# 1974  B-PER  B-PER
# ,  O  O
# 7–8  O  O
# .  O  O
#
# 93  O  O
# Böhme  O  O
# 1974  B-PER  B-PER
# ,  O  O
# 91  O  O
# ;  O  O
# Bücker  O  O
# 1997  B-PER  B-PER
# ,  O  O
# 137–140  O  O
# .  O  O
#
# 7  O  O
# und  O  O
# 10  O  O
# )  O  O
# im  O  O
# Alter  O  O
# zwischen  O  O
# 40  O  O
# und  O  O
# 60  O  O
# Jahren  O  O
# verstarben  O  O
# .  O  O
#
# Die  O  O
# Zahl  O  O
# der  O  O
# Toten  O  O
# ,  O  O
# die  O  O
# das  O  O
# 50  O  O
# .  O  O
#
# Lebensjahr  O  O
# nicht  O  O
# erreichten  O  O
# ,  O  O
# ist  O  O
# damit  O  O
# im  O  O
# Vergleich  O  O
# zu  O  O
# denen  O  O
# ,  O  O
# die  O  O
# dieses  O  O
# Alter  O  O
# überschritten  O  O
# ,  O  O
# relativ  O  O
# hoch  O  O
# .  O  O
#
# Tierknochen  B-ART  B-ART
# wurden  O  O
# in  O  O
# Grab  B-CON  B-CON
# 39  O  O
# des  O  O
# östlichen  O  O
# Ausgrabungsareales  B-CON  O
# sowie  O  O
# in  O  O
# fünf  O  O
# Gräbern  B-CON  B-CON
# des  O  O
# westlichen  O  O
# Teils  O  O
# der  O  O
# Nekropole  B-CON  B-CON
# (  O  O
# Grab  B-CON  B-CON
# 6  O  O
# ,  O  O
# 7  O  O
# ,  O  O
# 11  O  O
# ,  O  O
# 17  O  O
# ,  O  O
# 28  O  O
# )  O  O
# innerhalb  O  O
# des  O  O
# Leichenbrandes  B-CON  O
# nachgewiesen  O  O
# ,  O  O
# von  O  O
# denen  O  O
# das  O  O
# Grab  B-CON  B-CON
# 11  O  O
# jedoch  O  O
# keine  O  O
# datierenden  O  O
# Beigaben  O  O
# aufwies  O  O
# .  O  O
#
# In  O  O
# drei  O  O
# Gräbern  B-CON  B-CON
# konnten  O  O
# diese  O  O
# als  O  O
# Schweineknochen  B-ART  B-ART
# identifiziert  O  O
# werden  O  O
# .  O  O
#
# Es  O  O
# ist  O  O
# jedoch  O  O
# kein  O  O
# Muster  O  O
# bei  O  O
# der  O  O
# Mitverbrennung  O  O
# von  O  O
# Tierresten  O  O
# erkennbar  O  O
# .  O  O
#
# Die  O  O
# verbrannten  O  B-ART
# Knochen  B-ART  I-ART
# stammen  O  O
# aus  O  O
# Frauen-  B-CON  O
# ,  I-CON  O
# Männer-  I-CON  B-CON
# und  I-CON  I-CON
# Kindergräbern  I-CON  I-CON
# .  O  O
#
# Das  O  O
# Grab  B-CON  B-CON
# 39  O  O
# beinhaltete  O  O
# des  O  O
# Weiteren  O  O
# einen  O  O
# Obstkern  B-ART  O
# ,  O  O
# der  O  O
# nicht  O  O
# bestimmt  O  O
# ist  O  O
# .  O  O
#
# Es  O  O
# könnte  O  O
# sich  O  O
# um  O  O
# eine  O  O
# Speisebeigabe  O  O
# handeln  O  O
# .  O  O
#
# Die  O  O
# Beigaben  O  O
# aus  O  O
# allen  O  O
# Brandgräbern  B-CON  O
# lagen  O  O
# durchweg  O  O
# auf  O  O
# dem  O  O
# Scheiterhaufen  O  O
# oder  O  O
# wurden  O  O
# im  O  O
# Rahmen  O  O
# anderer  O  O
# Bestattungszeremonien  O  O
# verbrannt  O  O
# .  O  O
#
# Sie  O  O
# sind  O  O
# stark  O  O
# fragmentiert  O  O
# und  O  O
# weisen  O  O
# zum  O  O
# Teil  O  O
# sichtbare  O  O
# Spuren  O  O
# von  O  O
# Verbrennung  O  O
# auf  O  O
# .  O  O
#
# Die  O  O
# Keramik  B-ART  B-ART
# ist  O  O
# oft  O  O
# abgeplatzt  O  O
# oder  O  O
# stark  O  O
# verzogen  O  O
# ,  O  O
# Glas  B-MAT  O
# ist  O  O
# zu  O  O
# Klumpen  B-ART  O
# geschmolzen  O  O
# oder  O  O
# bis  O  O
# auf  O  O
# Ausnahmen  O  O
# deformiert  O  O
# und  O  O
# von  O  O
# den  O  O
# Buntmetallobjekten  B-ART  O
# sind  O  O
# durchweg  O  O
# nur  O  O
# sehr  O  O
# kleine  O  O
# Bruchstücke  O  O
# vorhanden  O  O
# .  O  O
#
# Eine  O  O
# weitere  O  O
# Filterwirkung  O  O
# für  O  O
# die  O  O
# Überlieferung  O  O
# der  O  O
# Beigaben  O  O
# besitzt  O  O
# die  O  O
# bewusste  O  O
# oder  O  O
# unbewusste  O  O
# Auslese  O  O
# der  O  O
# Scheiterhaufenrückstände  B-ART  O
# .  O  O
#
# Die  O  O
# Analyse  O  O
# der  O  O
# verlagerten  O  O
# Scheiterhaufenreste  B-ART  O
# von  O  O
# Herzebrock-Clarholz  B-LOC  O
# zeigte  O  O
# ,  O  O
# dass  O  O
# ihre  O  O
# Zusammensetzung  O  O
# von  O  O
# derjenigen  O  O
# der  O  O
# Grabinventare  O  O
# abwich  O  O
# .  O  O
#
# Stadt  O  O
# zwar  O  O
# eine  O  O
# gewisse  O  O
# Bedeutung  O  O
# verlieh  O  O
# ,  O  O
# ihr  O  O
# aber  O  O
# auch  O  O
# die  O  O
# Hauptlast  O  O
# mancher  O  O
# Angriffe  O  O
# eintrug  O  O
# .  O  O
#
# Nachdem  O  O
# Kaiser  O  O
# Karl  O  O
# v.  O  O
# 1543  B-PER  O
# sowohl  O  O
# Herr  O  O
# des  O  O
# Nedersticht  O  O
# als  O  O
# auch  O  O
# des  O  O
# angrenzenden  O  O
# Gelre  O  O
# geworden  O  O
# war  O  O
# ,  O  O
# verlor  O  O
# sie  O  O
# ihre  O  O
# Funktion  O  O
# .  O  O

# %%
#work out which of the transitions are most likely in descending order
from collections import Counter

def print_transitions(trans_features):
    for (label_from, label_to), weight in trans_features:
        print("%-6s -> %-7s %0.6f" % (label_from, label_to, weight))

#what are the 20 most likely transitions
print("Top likely transitions:")
print_transitions(Counter(crf.transition_features_).most_common(20))

#what are the 20 least likely transitions
print("\nTop unlikely transitions:")
print_transitions(Counter(crf.transition_features_).most_common()[-20:])
# Out:
# Top likely transitions:
# I-ART  -> I-ART   5.709914
# B-ART  -> I-ART   5.268014
# I-MAT  -> I-MAT   5.051077
# I-PER  -> I-PER   4.775873
# I-CON  -> I-CON   4.454418
# B-SPE  -> I-SPE   4.401258
# B-PER  -> I-PER   4.330284
# I-SPE  -> I-SPE   4.158327
# B-MAT  -> I-MAT   4.059485
# B-CON  -> I-CON   3.797470
# I-LOC  -> I-LOC   3.660770
# B-LOC  -> I-LOC   3.124166
# O      -> O       2.539505
# O      -> B-PER   1.316442
# O      -> B-ART   0.911409
# O      -> B-LOC   0.811756
# O      -> B-CON   0.515187
# I-CON  -> O       0.491752
# B-PER  -> B-CON   0.400941
# B-MAT  -> B-ART   0.327588
#
# Top unlikely transitions:
# B-LOC  -> I-PER   -2.368283
# B-ART  -> I-LOC   -2.377898
# B-ART  -> I-CON   -2.387682
# I-PER  -> I-CON   -2.453047
# B-PER  -> I-LOC   -2.469888
# B-MAT  -> I-CON   -2.560051
# B-ART  -> I-PER   -2.632507
# B-LOC  -> I-ART   -2.657297
# B-CON  -> I-PER   -2.664173
# B-PER  -> I-ART   -2.838070
# B-CON  -> I-LOC   -3.122502
# B-SPE  -> B-PER   -3.161820
# B-LOC  -> I-CON   -3.681451
# B-PER  -> I-CON   -4.001483
# O      -> I-SPE   -4.002238
# O      -> I-MAT   -4.504281
# O      -> I-ART   -5.658613
# O      -> I-PER   -6.411332
# O      -> I-LOC   -6.706831
# O      -> I-CON   -6.776857

# %%
#What aspects of the terms make it likely to be that tag
def print_state_features(state_features):
    for (attr, label), weight in state_features:
        print("%0.6f %-8s %s" % (weight, label, attr))    

#what are the 30 most likely aspects
print("Top positive:")
print_state_features(Counter(crf.state_features_).most_common(30))

#what 30 aspects make it least likely to be that term
print("\nTop negative:")
print_state_features(Counter(crf.state_features_).most_common()[-30:])
# Out:
# Top positive:
# 6.524713 B-SPE    word.lower():roggen
# 6.350818 B-SPE    word.lower():menschlichen
# 6.344847 B-PER    word.lower():endneolithische
# 6.322654 B-SPE    word.lower():rinder
# 6.231904 B-SPE    word.lower():menschen
# 6.032314 B-LOC    word.lower():hoch-elten
# 6.015288 B-PER    word[-3:]:kum
# 5.925481 B-LOC    word.lower():dortmund-asseln
# 5.914191 B-LOC    word.lower():schwanfelder
# 5.850276 B-PER    word.lower():bandkeramisch
# 5.753214 B-SPE    word.lower():ziegen
# 5.659569 B-SPE    word.lower():rindern
# 5.612294 B-CON    word.lower():grabhügeln
# 5.607068 B-CON    word.lower():scherbenpackung
# 5.580278 B-PER    word.lower():jahrhundert
# 5.578876 B-ART    word.lower():fässer
# 5.538796 B-MAT    word.lower():eisen
# 5.527776 B-SPE    word.lower():erbsen
# 5.476352 B-LOC    word.lower():straubing-bogen
# 5.383564 B-ART    word.lower():spaltbohlen
# 5.337073 B-ART    word.lower():schwellbalken
# 5.312048 B-CON    word.lower():brandbestattungen
# 5.292746 B-MAT    word.lower():hölzernen
# 5.284173 B-CON    word[-3:]:rab
# 5.201333 B-ART    word.lower():gerate
# 5.155716 B-PER    word.lower():spätneolithische
# 5.104715 B-SPE    word.lower():einkorn
# 5.088009 B-CON    word.lower():moorfund
# 5.060377 B-SPE    word.lower():ölsaaten
# 5.058911 B-PER    word[-3:]:998
#
# Top negative:
# -2.299380 O        -1:word.lower():hofplatz
# -2.300046 O        word[-3:]:fäß
# -2.342593 O        word.lower():neolithische
# -2.343812 O        -1:word.lower():keramik‐
# -2.363026 O        +2:word.lower():nahtrinne
# -2.374256 O        -1:word.lower():eggers
# -2.469239 O        word[-3:]:las
# -2.470513 O        word[-3:]:wig
# -2.479536 O        +2:word.lower():rückenlage
# -2.480153 O        word.lower():kellers
# -2.515885 O        word.lower():knochenerhaltung
# -2.521215 O        -1:word.lower():jn
# -2.528760 O        word.lower():ühlengrund
# -2.537369 O        word[-3:]:463
# -2.562325 O        +2:word.lower():chr.
# -2.606020 O        word.lower():jungneolithischen
# -2.649183 O        word.lower():halle
# -2.662336 O        word.lower():holzkeller
# -2.672875 O        word[-3:]:rge
# -2.685876 I-ART    -1:word.lower():randständigem
# -2.734359 O        word.lower():siedlung
# -2.753364 O        word.lower():eingrabung
# -2.776980 O        word[-3:]:rne
# -2.790528 O        word.lower():2015
# -2.863353 O        word[-3:]:LBK
# -2.995808 O        -1:word.lower():gelegene
# -3.009405 O        word.lower():steinsetzung
# -3.015686 O        word.lower():bestattung
# -3.179508 O        word.lower():pfosten
# -3.298083 B-PER    -1:word.lower():zwischen

# %%
## optional: do hyperparameter tuning

# %%
# %%time 
# this is to work out the best parameters for the testing. not needed yet but can increase the results 
# define fixed parameters and parameters to search
crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs', 
    max_iterations=100, 
    all_possible_transitions=True
)
params_space = {
    'c1': scipy.stats.expon(scale=0.5),
    'c2': scipy.stats.expon(scale=0.05),
}

# use the same metric for evaluation
f1_scorer = make_scorer(metrics.flat_f1_score, 
                        average='weighted', labels=labels)

# search
rs = RandomizedSearchCV(crf, params_space, 
                        cv=3, 
                        verbose=1, 
                        n_jobs=-1, 
                        n_iter=50, 
                        scoring=f1_scorer,
                        return_train_score = True)
rs.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:25
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\model_selection\_search.py:875, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     869     results = self._format_results(
#     870         all_candidate_params, n_splits, all_out, all_more_results
#     871     )
#     873     return results
# --> 875 self._run_search(evaluate_candidates)
#     877 # multimetric is determined here because in the case of a callable
#     878 # self.scoring the return type is only known after calling
#     879 first_test_score = all_out[0]["test_scores"]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\model_selection\_search.py:1753, in RandomizedSearchCV._run_search(self, evaluate_candidates)
#    1751 def _run_search(self, evaluate_candidates):
#    1752     """Search n_iter candidates from param_distributions"""
# -> 1753     evaluate_candidates(
#    1754         ParameterSampler(
#    1755             self.param_distributions, self.n_iter, random_state=self.random_state
#    1756         )
#    1757     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\model_selection\_search.py:822, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     814 if self.verbose > 0:
#     815     print(
#     816         "Fitting {0} folds for each of {1} candidates,"
#     817         " totalling {2} fits".format(
#     818             n_splits, n_candidates, n_candidates * n_splits
#     819         )
#     820     )
# --> 822 out = parallel(
#     823     delayed(_fit_and_score)(
#     824         clone(base_estimator),
#     825         X,
#     826         y,
#     827         train=train,
#     828         test=test,
#     829         parameters=parameters,
#     830         split_progress=(split_idx, n_splits),
#     831         candidate_progress=(cand_idx, n_candidates),
#     832         **fit_and_score_kwargs,
#     833     )
#     834     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     835         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     836     )
#     837 )
#     839 if len(out) < 1:
#     840     raise ValueError(
#     841         "No fits were performed. "
#     842         "Was the CV iterator empty? "
#     843         "Were there no candidates?"
#     844     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\joblib\parallel.py:1054, in Parallel.__call__(self, iterable)
#    1051     self._iterating = False
#    1053 with self._backend.retrieval_context():
# -> 1054     self.retrieve()
#    1055 # Make sure that we get a last message telling us we are done
#    1056 elapsed_time = time.time() - self._start_time
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\joblib\parallel.py:933, in Parallel.retrieve(self)
#     931 try:
#     932     if getattr(self._backend, 'supports_timeout', False):
# --> 933         self._output.extend(job.get(timeout=self.timeout))
#     934     else:
#     935         self._output.extend(job.get())
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\joblib\_parallel_backends.py:542, in LokyBackend.wrap_future_result(future, timeout)
#     539 """Wrapper for Future.result to implement the same behaviour as
#     540 AsyncResults.get from multiprocessing."""
#     541 try:
# --> 542     return future.result(timeout=timeout)
#     543 except CfTimeoutError as e:
#     544     raise TimeoutError from e
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.9_3.9.3568.0_x64__qbz5n2kfra8p0\lib\concurrent\futures\_base.py:441, in Future.result(self, timeout)
#     438 elif self._state == FINISHED:
#     439     return self.__get_result()
# --> 441 self._condition.wait(timeout)
#     443 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     444     raise CancelledError()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.9_3.9.3568.0_x64__qbz5n2kfra8p0\lib\threading.py:312, in Condition.wait(self, timeout)
#     310 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311     if timeout is None:
# --> 312         waiter.acquire()
#     313         gotit = True
#     314     else:
#
# KeyboardInterrupt:

# %%
# crf = rs.best_estimator_  # shows that the best params are 
print('best params:', rs.best_params_)
print('best CV score:', rs.best_score_)
print('model size: {:0.2f}M'.format(rs.best_estimator_.size_ / 1000000))

# %%
#rs.cv_results_["mean_test_score"]
rs.cv_results_.keys()

# %%
#_x = [s.parameters['c1'] for s in rs.grid_scores_]
#_y = [s.parameters['c2'] for s in rs.grid_scores_]
#_c = [s.mean_validation_score for s in rs.grid_scores_]

_x = [s['c1'] for s in rs.cv_results_['params']]
_y = [s['c2'] for s in rs.cv_results_['params']]
_c = [s for s in rs.cv_results_['mean_train_score']]

fig = plt.figure()
fig.set_size_inches(12, 12)
ax = plt.gca()
ax.set_yscale('log')
ax.set_xscale('log')
ax.set_xlabel('C1')
ax.set_ylabel('C2')
ax.set_title("Randomized Hyperparameter Search CV Results (min={:0.3}, max={:0.3})".format(
    min(_c), max(_c)
))

ax.scatter(_x, _y, c=_c, s=60, alpha=0.9, edgecolors=[0,0,0])

print("Dark blue => {:0.4}, dark red => {:0.4}".format(min(_c), max(_c)))

# %%
crf = rs.best_estimator_
y_pred = crf.predict(X_test)
print(metrics.flat_classification_report(
    y_test, y_pred, labels=sorted_labels, digits=3
))
